# %%
from src.plot_scatter import plot_scatter
from src.plot_manual_cross_section import overlay_manual_cross_section
from src.plot_fit_constraints import plot_fit_constraints
from src.plot_gundam_stacked import plot_gundam_stacked
from src.plot_GENIE_NUISANCE import overlay_genie_nuisance_xsec

# %%
# Pre-fit plot
fig, axes = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/prefit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root',
    sample_name='selection_reco_dpT',
    variable_name='reco_dpT',
    cov_bin_range=(0, 12), # Covariance matrix elm, cont all range (overflow bin inclusive)
    fit_type='pre-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Pre-fit' + '\n' + 'Work-in-Progress',
    output_file='Plots/Asimov/Prefits/prefit_dpT.png',
    pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
)

# Post-fit plot with custom settings
fig, axes = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/postfit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root',
    sample_name='selection_reco_dpT',
    variable_name='reco_dpT',
    cov_bin_range=(0, 12), # Covariance matrix elm, cont all range (overflow bin inclusive)
    fit_type='post-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Post-fit' + '\n' + 'Work-in-Progress',
    pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
    output_file='Plots/Asimov/Postfits/postfit_dpT.png'
)

# %%
# Pre-fit plot
fig, axes = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/prefit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root',
    sample_name='sideband_reco_dpT',
    variable_name='reco_dpT',
    cov_bin_range=(13, 25), # Covariance matrix elm
    fit_type='pre-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Pre-fit' + '\n' + 'Work-in-Progress',
    output_file='Plots/Asimov/Prefits/prefit_dpT_sideband.png',
    pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
)

# Post-fit plot with custom settings
fig, axes = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/postfit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root',
    sample_name='sideband_reco_dpT',
    variable_name='reco_dpT',
    cov_bin_range=(13, 25), # Covariance matrix elm
    fit_type='post-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Post-fit' + '\n' + 'Work-in-Progress',
    pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
    output_file='Plots/Asimov/Postfits/postfit_dpT_sideband.png'
)

# %%
fig_xs, ax_xs = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/XSection/XSec_dpT.root',
        is_cross_section = True,
        hist_path="calcXsec/histograms/True_dpT_XS_TH1D;1",
        xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
        ylabel=r'$\frac{d\sigma}{d\delta p_T}$ $\left[\frac{cm^2}{(GeV/c)Ar}\right]$ $\times 10^{-37}$',
        bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label="GUNDAM Asimov Extraction",
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        scaling_power_of_10=1e40
)
fig_xs.savefig('Plots/Asimov/XSection/dpT_XS.png', dpi=300, bbox_inches='tight')

# %%
bins_mev = [(0, 80), (80, 160), (160, 240), (240, 320), (320, 520), (520, 800), (800, 1000)]
# Overlay manual calculation
fig, ax, xs = overlay_manual_cross_section(
    fig=fig_xs,
    ax=ax_xs,
    signal_tree_path="events/full/signal",
    root_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    bins_mev=bins_mev,
    n_targets=4.6079073e30,
    flux=1.075491e+11,
    color='green',
    marker='s',
    label=r'Signal Histogram Divided by Bin-Width, Flux, and $N_{Target}$',
    variable_name="true_dpT",
    scaling_power_of_10=1e37,
    energy_conversion=True
)
fig.savefig('Plots/Asimov/XSection/dpT_XS_wSignal.png', dpi=300, bbox_inches='tight')
display(fig)
# Out:
# ...
# Signal Events and Cross-Section per True Bin
# ...
# Bin Range (MeV/c)         N_Signal     Bin Width (MeV)    σ (x10^-37 cm²/GeV)
# ------------------------------------------------------------------------------------------
#      0 - 80     MeV/c    2943         80                 7.010443e-01
#     80 - 160    MeV/c    5342         80                 1.272782e+00
#    160 - 240    MeV/c    4718         80                 1.124276e+00
#    240 - 320    MeV/c    2894         80                 6.904884e-01
#    320 - 520    MeV/c    4491         200                4.292153e-01
#    520 - 800    MeV/c    2774         280                1.900049e-01
#    800 - 1000   MeV/c    650          200                6.267671e-02
# ------------------------------------------------------------------------------------------
# Total                     23812
# ...

# %%
# Using Jaesung's Flux (times e11)
(1.47e20*8.3525537e11/(1.0900766e21))/1e11
# Out:
# 1.1263661598643617

# %%
fig_genie, ax_genie, xsec_genie = overlay_genie_nuisance_xsec(
    fig_xs, ax_xs,
    nuisance_file_dir = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    bin_edges         = [0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.80],
    nuisance_var      = 'ICARUS_1muNp0pi_deltaPT',
    scaling_power_of_10 = 1e37,   # match whatever scaling you used in plot_scatter
    label             = 'GENIE AR23_20i'
)
fig_genie.savefig('Plots/Asimov/XSection/dpT_XS_wGENIE.png', dpi=300, bbox_inches='tight')
display(fig_genie)
# Out:
# ...
# GENIE NUISANCE Cross-Section (ICARUS_1muNp0pi_deltaPT)
# ...
# Bin range                                 xsec
# ----------------------------------------------------------------------
#   0.0000 – 0.0800           7.115953e-01
#   0.0800 – 0.1600           1.305762e+00
#   0.1600 – 0.2400           1.202712e+00
#   0.2400 – 0.3200           7.711200e-01
#   0.3200 – 0.5200           5.581808e-01
#   0.5200 – 0.8000           2.862805e-01
# ...

# %%
fig_genie, ax_genie, xsec_genie = overlay_genie_nuisance_xsec(
    fig_xs, ax_xs,
    nuisance_file_dir = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/tests-numu",
    nuisance_file_dir_numubar = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/tests-numubar",
    bin_edges         = [0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.80],
    nuisance_var      = 'ICARUS_1muNp0pi_deltaPT',
    scaling_power_of_10 = 1e37,   # match whatever scaling you used in plot_scatter
    label             = 'GENIE AR23_20i'
)
fig_genie.savefig('Plots/Asimov/XSection/dpT_XS_wGENIE.png', dpi=300, bbox_inches='tight')
display(fig_genie)
# Out:
# ...
# GENIE NUISANCE Cross-Section (ICARUS_1muNp0pi_deltaPT)
# ...
# Bin range                                 xsec
# ----------------------------------------------------------------------
#   0.0000 – 0.0800           7.110496e-01
#   0.0800 – 0.1600           1.306504e+00
#   0.1600 – 0.2400           1.207081e+00
#   0.2400 – 0.3200           7.702653e-01
#   0.3200 – 0.5200           5.572394e-01
#   0.5200 – 0.8000           2.863141e-01
# ...

# %%
fig_template, ax_template = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root',
        is_cross_section = False,
        hist_path="FitterEngine/postFit/Hesse/errors/Template Parameter true_dpT/values/postFitErrors_TH1D;1",
        xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
        ylabel='$\mathbf{Template\ Parameter\ Value\ Post-fit}$',
        bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label=None,
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT'
)
fig_template.savefig('Plots/Asimov/TemplateParameters/dpT.png', dpi=300, bbox_inches='tight')

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root",
    figsize=(7, 10),
    directory_path="FitterEngine/postFit/Hesse/errors/Cross section Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress'
)
fig.savefig('Plots/Asimov/NuisanceParameters/dpT_InteractionModel.png', dpi=300, bbox_inches='tight')
# Out:
# Number of parameters: 52

# %%
fig_xs, ax_xs = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/XSection/XSec_dalphaT.root',
        is_cross_section = True,
        hist_path="calcXsec/histograms/True_dalphaT_XS_TH1D;1",
        xlabel=r'$\mathbf{True}\ \delta \alpha_T\ \mathbf{[deg]}$',
        ylabel=r'$\frac{d\sigma}{d\delta \alpha_T}$ $\left[\frac{cm^2}{(degree)Ar}\right]$ $\times 10^{-40}$',
        bin_edges_labels=[0.0, 30.0, 60.0, 90.0, 120.0, 150.0, 180.0],
        is_y_errors = False,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label="GUNDAM Asimov Extraction",
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        remove_last_bin=False,
        scaling_power_of_10=1e40,
)
fig_xs.savefig('Plots/Asimov/XSection/dalphaT_XS.png', dpi=300, bbox_inches='tight')

# %%
bins_mev = [(0, 30), (30, 60), (60, 90), (90, 120), (120, 150), (150, 180)]
# Overlay manual calculation
fig, ax, xs = overlay_manual_cross_section(
    fig=fig_xs,
    ax=ax_xs,
    signal_tree_path="events/full/signal",
    root_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    bins_mev=bins_mev,
    n_targets=4.6079073e30,
    flux=1.075491e+11,
    color='green',
    marker='s',
    label=r'Signal Histogram Divided by Bin-Width, Flux, and $N_{Target}$',
    variable_name="true_dalphaT_deg",
    scaling_power_of_10=1e37,
    energy_conversion=False
)
fig.savefig('Plots/Asimov/XSection/dalphaT_XS_wSignal.png', dpi=300, bbox_inches='tight')
display(fig)
# Out:
# ...
# Signal Events and Cross-Section per True Bin
# ...
# Bin Range (MeV/c)         N_Signal     Bin Width (MeV)    σ (x10^-40 cm²/GeV)
# ------------------------------------------------------------------------------------------
#      0 - 30     MeV/c    2697         30                 1.814050e+00
#     30 - 60     MeV/c    2717         30                 1.827502e+00
#     60 - 90     MeV/c    3215         30                 2.162466e+00
#     90 - 120    MeV/c    3897         30                 2.621191e+00
#    120 - 150    MeV/c    5387         30                 3.623391e+00
#    150 - 180    MeV/c    6196         30                 4.167539e+00
# ------------------------------------------------------------------------------------------
# Total                     24109
# ...

# %%
fig_template, ax_template = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dalphaT.root',
        is_cross_section = False,
        hist_path="FitterEngine/postFit/Hesse/errors/Template Parameter true_dalphaT_deg/values/postFitErrors_TH1D;1",
        xlabel=r'$\mathbf{True}\ \delta \alpha_T\ \mathbf{[deg]}$',
        ylabel='$\mathbf{Template\ Parameter\ Value\ Post-fit}$',
        bin_edges_labels=[0.0, 30.0, 60.0, 90.0, 120.0, 150.0, 180.0],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label=None,
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        remove_last_bin=False
)
fig_template.savefig('Plots/Asimov/TemplateParameters/dalphaT.png', dpi=300, bbox_inches='tight')

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dalphaT.root",
    figsize=(7, 10),
    directory_path="FitterEngine/postFit/Hesse/errors/Cross section Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress'
)
fig.savefig('Plots/Asimov/NuisanceParameters/dalphaT_InteractionModel.png', dpi=300, bbox_inches='tight')
# Out:
# Number of parameters: 52

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd


def _read_nuisflat_enu(file_dir, bin_edges, flux_binwidth_divided=True):
    """
    Read all nuisflat files from one directory for Enu comparison.
    Returns (h_weighted, flux_integral, n_files).
    """
    files = sorted(glob.glob(f"{file_dir}/output_GENIE_*.nuisflat.root"))
    if not files:
        raise FileNotFoundError(f'No files found in {file_dir}')

    df_all = None
    flux_integral = None

    for f_path in files:
        with uproot.open(f_path) as f:
            df = f["FlatTree_VARS"].arrays(
                ["Enu_true", "InputWeight", "fScaleFactor", "ICARUS_1muNp0pi_IsSignal"],
                library="pd"
            )
            if df_all is None:
                df_all = df
                flux_hist = f["FlatTree_FLUX"].to_numpy()
                flux_integral = (
                    np.sum(flux_hist[0] * np.diff(flux_hist[1]))
                    if flux_binwidth_divided
                    else np.sum(flux_hist[0])
                )
                flux_integral *= 1e-4  # /m² → /cm²
            else:
                df_all = pd.concat([df_all, df], ignore_index=True)

    df_all["FinalWeight"] = df_all["InputWeight"] * df_all["fScaleFactor"]
    df_all["Enu_true_GeV"] = df_all["Enu_true"] * 1e-3
    df_sig = df_all.query("ICARUS_1muNp0pi_IsSignal == 1")

    h = np.histogram(df_sig["Enu_true_GeV"], bins=bin_edges,
                     weights=df_sig["FinalWeight"])[0]

    print(f"[NUISANCE] N total events:  {len(df_all)}")
    print(f"[NUISANCE] N signal events: {len(df_sig)}")

    return h, flux_integral, len(files)


def compare_enu_caf_vs_nuisance(
    caf_file_path,
    nuisance_file_dir,
    nuisance_file_dir_numubar=None,
    caf_tree_path="events/full/signal",
    bin_edges=np.linspace(0, 5, 51),
    normalize=True,
    label_caf_numu=r"Signal Tree ($\nu_\mu$)",
    label_caf_numubar=r"Signal Tree ($\bar{\nu}_\mu$)",
    label_numu=r"GENIE NUISANCE ($\nu_\mu$)",
    label_numubar=r"GENIE NUISANCE ($\bar{\nu}_\mu$)",
    figsize=(7, 6),
):
    bin_edges  = np.array(bin_edges)
    bin_widths = np.diff(bin_edges)

    # ── 1. Read CAF Enu + PDG ────────────────────────────────────────────────
    with uproot.open(caf_file_path) as f:
        tree = f[caf_tree_path]
        enu_caf = tree["true_neutrino_energy"].array(library="np")
        pdg_caf = tree["true_pdg"].array(library="np")
        ppfx_w  = tree["ppfx_cv_weight"].array(library="np")

    mask_numu    = pdg_caf ==  14
    mask_numubar = pdg_caf == -14

    print(f"[CAF] N events total:   {len(enu_caf)}")
    print(f"[CAF] N numu    (14):   {mask_numu.sum()}")
    print(f"[CAF] N numubar (-14):  {mask_numubar.sum()}")

    # ── 2. Read NUISANCE numu ────────────────────────────────────────────────
    h_numu, flux_numu, n_files_numu = _read_nuisflat_enu(nuisance_file_dir, bin_edges)
    print(f"[NUISANCE numu]    {n_files_numu} files, flux integral = {flux_numu:.4e} /cm²")
    print(f"[NUISANCE numu]    N signal events (weighted sum): {h_numu.sum():.2f}")

    # ── 3. Read NUISANCE numubar (optional) ──────────────────────────────────
    if nuisance_file_dir_numubar is not None:
        h_numubar, flux_numubar, n_files_numubar = _read_nuisflat_enu(
            nuisance_file_dir_numubar, bin_edges
        )
        print(f"[NUISANCE numubar] {n_files_numubar} files, flux integral = {flux_numubar:.4e} /cm²")

    # ── 4. Histogram CAF split by PDG ────────────────────────────────────────
    h_caf_numu,          _ = np.histogram(enu_caf[mask_numu], bins=bin_edges)
    h_caf_numu_weighted, _ = np.histogram(enu_caf[mask_numu], bins=bin_edges, weights=ppfx_w[mask_numu])
    h_caf_numubar,       _ = np.histogram(enu_caf[mask_numubar], bins=bin_edges, weights=ppfx_w[mask_numubar])

    h_numu_plot = h_numu / n_files_numu
    if nuisance_file_dir_numubar is not None:
        h_numubar_plot = h_numubar / n_files_numubar

    # ── 5. Normalize ─────────────────────────────────────────────────────────
    if normalize:
        h_caf_numu          = h_caf_numu          / (h_caf_numu.sum()          * bin_widths)
        h_caf_numu_weighted = h_caf_numu_weighted / (h_caf_numu_weighted.sum() * bin_widths)
        h_caf_numubar       = h_caf_numubar       / (h_caf_numubar.sum()       * bin_widths)
        h_numu_plot         = h_numu_plot          / (h_numu_plot.sum()         * bin_widths)
        if nuisance_file_dir_numubar is not None:
            h_numubar_plot = h_numubar_plot / (h_numubar_plot.sum() * bin_widths)

    # ── 6. Plot ──────────────────────────────────────────────────────────────
    fig_numu, ax_numu = plt.subplots(figsize=figsize)

    ax_numu.step(bin_edges, np.append(h_caf_numu, h_caf_numu[-1]),
                 where="post", label=label_caf_numu, linewidth=1.8, color='C0')
    ax_numu.step(bin_edges, np.append(h_caf_numu_weighted, h_caf_numu_weighted[-1]),
                 where="post", label=r"Signal Tree PPFX ($\nu_\mu$)", linewidth=1.8, color='C0', linestyle='--')
    ax_numu.step(bin_edges, np.append(h_numu_plot, h_numu_plot[-1]),
                 where="post", label=label_numu, linewidth=1.8, color='C1')

    ax_numu.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]", fontsize=13)
    ax_numu.set_xlim(bin_edges[0], bin_edges[-1])
    ax_numu.set_ylim(bottom=0)
    ax_numu.legend(fontsize=11)

    if nuisance_file_dir_numubar is not None:
        fig_numubar, ax_numubar = plt.subplots(figsize=figsize)

        ax_numubar.step(bin_edges, np.append(h_caf_numubar, h_caf_numubar[-1]),
                        where="post", label=label_caf_numubar, linewidth=1.8, color='C0')
        ax_numubar.step(bin_edges, np.append(h_numubar_plot, h_numubar_plot[-1]),
                        where="post", label=label_numubar, linewidth=1.8, color='C1')

        ax_numubar.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]", fontsize=13)
        ax_numubar.set_xlim(bin_edges[0], bin_edges[-1])
        ax_numubar.set_ylim(bottom=0)
        ax_numubar.legend(fontsize=11)

        return fig_numu, ax_numu, fig_numubar, ax_numubar

    return fig_numu, ax_numu

# %%
fig_numu, ax_numu, fig_numubar, ax_numubar = compare_enu_caf_vs_nuisance(
    caf_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    nuisance_file_dir="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    normalize=True
)
plt.show()
# Out:
# [CAF] N events total:   24109
# [CAF] N numu    (14):   22670
# [CAF] N numubar (-14):  1439
# [NUISANCE] N total events:  10000000
# [NUISANCE] N signal events: 4904451
# [NUISANCE numu]    10 files, flux integral = 4.6163e-10 /cm²
# [NUISANCE numu]    N signal events (weighted sum): 0.00
# [NUISANCE] N total events:  10000000
# [NUISANCE] N signal events: 2048777
# [NUISANCE numubar] 10 files, flux integral = 2.6999e-10 /cm²

# %%
with uproot.open("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root") as f:
    tree = f["events/full/signal"]
    enu = tree["true_neutrino_energy"].array(library="np")
    pdg = tree["true_pdg"].array(library="np")
    ppfx_w = tree["ppfx_cv_weight"].array(library="np")

mask_numu = pdg == 14
bin_edges = np.linspace(0, 5, 51)

h_unweighted, _ = np.histogram(enu[mask_numu], bins=bin_edges)
h_weighted,   _ = np.histogram(enu[mask_numu], bins=bin_edges, weights=ppfx_w[mask_numu])

ratio = np.where(h_unweighted > 0, h_weighted / h_unweighted, 1.0)

bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])
plt.figure()
plt.step(bin_centers, ratio)
plt.xlabel(r"$E_\nu^{\rm true}$ [GeV]")
plt.ylabel("weighted / unweighted")
plt.title("Effect of ppfx_cv_weight")
plt.axhline(1.0, color='k', linestyle='--')
plt.show()
# Out:
# /var/folders/hn/gg8vh0yd4j1382jb74b5wr780000gn/T/ipykernel_7734/128274870.py:13: RuntimeWarning: invalid value encountered in divide
#   ratio = np.where(h_unweighted > 0, h_weighted / h_unweighted, 1.0)

# %%
with uproot.open("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root") as f:
    tree = f["events/full/signal"]
    enu = tree["true_neutrino_energy"].array(library="np")
    pdg = tree["true_pdg"].array(library="np")
    ppfx_w = tree["ppfx_cv_weight"].array(library="np")

mask_numu = pdg == 14
bin_edges = np.linspace(0, 5, 51)
bin_widths = np.diff(bin_edges)

h_unweighted, _ = np.histogram(enu[mask_numu], bins=bin_edges)
h_weighted,   _ = np.histogram(enu[mask_numu], bins=bin_edges, weights=ppfx_w[mask_numu])

fig, ax = plt.subplots()
ax.step(bin_edges, np.append(h_unweighted, h_unweighted[-1]),
        where="post", label="Before PPFX", linewidth=1.8, color='C0')
ax.step(bin_edges, np.append(h_weighted, h_weighted[-1]),
        where="post", label="After PPFX", linewidth=1.8, color='C1')
ax.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]")
ax.set_xlim(0, 5)
ax.set_ylim(bottom=0)
ax.legend()
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt

file_path_genie_single = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/output_GENIE_0.nuisflat.root"

file_path_genie_fhc = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14/output_GENIE_0.nuisflat.root"

caf_file_path = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root"

bin_edges = np.linspace(0, 5, 51)
bin_widths = np.diff(bin_edges)

def read_nuisflat(file_path):
    with uproot.open(file_path) as f:
        df = f["FlatTree_VARS"].arrays(
            ["Enu_true", "InputWeight", "fScaleFactor", "ICARUS_1muNp0pi_IsSignal"],
            library="pd"
        )
    df["FinalWeight"] = df["InputWeight"] * df["fScaleFactor"]
    df["Enu_true_GeV"] = df["Enu_true"] * 1e-3
    df_sig = df.query("ICARUS_1muNp0pi_IsSignal == True")
    print(f"[{file_path.split('/')[-2]}] N total: {len(df)}, N signal: {len(df_sig)}")
    h, _ = np.histogram(df_sig["Enu_true_GeV"], bins=bin_edges, weights=df_sig["FinalWeight"])
    return h / (h.sum() * bin_widths)

h_genie_single = read_nuisflat(file_path_genie_single)
h_genie_fhc    = read_nuisflat(file_path_genie_fhc)

# ── CAF ───────────────────────────────────────────────────────────────────
with uproot.open(caf_file_path) as f:
    tree = f["events/full/signal"]
    enu_caf = tree["true_neutrino_energy"].array(library="np")
    pdg_caf = tree["true_pdg"].array(library="np")

mask_numu = pdg_caf == 14
print(f"[CAF] N total: {len(enu_caf)}, N numu: {mask_numu.sum()}")
h_caf, _ = np.histogram(enu_caf[mask_numu], bins=bin_edges)
h_caf = h_caf / (h_caf.sum() * bin_widths)

# ── Jaesung file ──────────────────────────────────────────────────────────
with uproot.open(jaesung_path) as f:
    tree_j = f["AllSamples_FillTree/trueEvents_NSigmas"]
    df_j = tree_j.arrays(["TrueE", "TruePDG", "IsSignal", "FluxWeightWithG4Update"], library="pd")

df_j_sig = df_j.query("IsSignal == True and TruePDG == 14")
print(f"[Jaesung] N total: {len(df_j)}, N signal numu: {len(df_j_sig)}")
h_jaesung, _ = np.histogram(df_j_sig["TrueE"], bins=bin_edges, weights=df_j_sig["FluxWeightWithG4Update"])
h_jaesung = h_jaesung / (h_jaesung.sum() * bin_widths)

# ── Build g3chase weight lookup and apply to CAF ──────────────────────────
bin_edges_w = np.linspace(0, 20, 201)
h_sum_w, _  = np.histogram(df_j["TrueE"], bins=bin_edges_w, weights=df_j["FluxWeightWithG4Update"])
h_counts, _ = np.histogram(df_j["TrueE"], bins=bin_edges_w)
avg_weight  = np.where(h_counts > 0, h_sum_w / h_counts, 1.0)

bin_idx  = np.searchsorted(bin_edges_w, enu_caf[mask_numu], side="right") - 1
bin_idx  = np.clip(bin_idx, 0, len(avg_weight) - 1)
g3chase_w = avg_weight[bin_idx]

h_caf_g3chase, _ = np.histogram(enu_caf[mask_numu], bins=bin_edges, weights=g3chase_w)
h_caf_g3chase = h_caf_g3chase / (h_caf_g3chase.sum() * bin_widths)

# ── Plot ──────────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(7, 6))
ax.step(bin_edges, np.append(h_caf, h_caf[-1]),
        where="post", linewidth=1.8, color='C0', label=r"Signal Tree (Renzo)")
#ax.step(bin_edges, np.append(h_jaesung, h_jaesung[-1]),
#        where="post", linewidth=1.8, color='C3', label="Signal Tree (Jaesung)")
ax.step(bin_edges, np.append(h_genie_fhc, h_genie_fhc[-1]),
        where="post", linewidth=1.8, color='C2', label="GENIE (Renzo)")
#ax.step(bin_edges, np.append(h_genie_single, h_genie_single[-1]),
#        where="post", linewidth=1.8, color='C1', label="GENIE (Jaesung)")
ax.step(bin_edges, np.append(h_caf_g3chase, h_caf_g3chase[-1]),
        where="post", linewidth=1.8, color='C4', linestyle='--',
        label=r"Signal Tree Renzo (G3Chase+G4Update)")

ax.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]", fontsize=13)
ax.set_xlim(0, 5)
ax.set_ylim(bottom=0)
ax.legend(fontsize=11)
plt.show()
# Out:
# [data] N total: 1000000, N signal: 282088
# [fhc_Nu14] N total: 1000000, N signal: 490806
# [CAF] N total: 24109, N numu: 22670
# [Jaesung] N total: 166489, N signal numu: 155164
# /var/folders/hn/gg8vh0yd4j1382jb74b5wr780000gn/T/ipykernel_34135/2773676719.py:55: RuntimeWarning: invalid value encountered in divide
#   avg_weight  = np.where(h_counts > 0, h_sum_w / h_counts, 1.0)

# %%
with uproot.open(jaesung_path) as f:
    tree_j = f["AllSamples_FillTree/trueEvents_NSigmas"]
    flux_w = tree_j["FluxWeightWithG4Update"].array(library="np")
    true_e = tree_j["TrueE"].array(library="np")

fig, ax = plt.subplots(figsize=(7, 6))
ax.scatter(true_e, flux_w, s=1, alpha=0.3, color='C0')
ax.set_xlabel(r"$E_\nu^{\rm true}$", fontsize=13)
ax.set_ylabel("FluxWeightWithG4Update", fontsize=13)
ax.set_ylim(bottom=0)
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd


def _read_nuisflat_enu(file_dir, bin_edges, flux_binwidth_divided=True):
    files = sorted(glob.glob(f"{file_dir}/output_GENIE_*.nuisflat.root"))
    if not files:
        raise FileNotFoundError(f'No files found in {file_dir}')

    df_all = None
    flux_integral = None

    for f_path in files:
        with uproot.open(f_path) as f:
            df = f["FlatTree_VARS"].arrays(
                ["Enu_true", "InputWeight", "fScaleFactor", "ICARUS_1muNp0pi_IsSignal"],
                library="pd"
            )
            if df_all is None:
                df_all = df
                flux_hist = f["FlatTree_FLUX"].to_numpy()
                flux_integral = (
                    np.sum(flux_hist[0] * np.diff(flux_hist[1]))
                    if flux_binwidth_divided
                    else np.sum(flux_hist[0])
                )
                flux_integral *= 1e-4
            else:
                df_all = pd.concat([df_all, df], ignore_index=True)

    df_all["FinalWeight"] = df_all["InputWeight"] * df_all["fScaleFactor"]
    df_all["Enu_true_GeV"] = df_all["Enu_true"] * 1e-3
    df_sig = df_all.query("ICARUS_1muNp0pi_IsSignal == 1")

    print(f"[NUISANCE] N total events:  {len(df_all)}")
    print(f"[NUISANCE] N signal events: {len(df_sig)}")

    h = np.histogram(df_sig["Enu_true_GeV"], bins=bin_edges,
                     weights=df_sig["FinalWeight"])[0]
    return h, flux_integral, len(files)


def compare_enu_caf_vs_nuisance(
    caf_file_path,
    flux_file_path,
    nuisance_file_dir,
    nuisance_file_dir_numubar=None,
    caf_tree_path="events/full/signal",
    bin_edges=np.linspace(0, 5, 51),
    normalize=True,
    label_caf_numu=r"Signal Tree ($\nu_\mu$)",
    label_caf_numubar=r"Signal Tree ($\bar{\nu}_\mu$)",
    label_numu=r"GENIE NUISANCE ($\nu_\mu$)",
    label_numubar=r"GENIE NUISANCE ($\bar{\nu}_\mu$)",
    figsize=(7, 6),
):
    bin_edges  = np.array(bin_edges)
    bin_widths = np.diff(bin_edges)

    # ── 1. Read CAF Enu + PDG ────────────────────────────────────────────────
    with uproot.open(caf_file_path) as f:
        tree = f[caf_tree_path]
        enu_caf = tree["true_neutrino_energy"].array(library="np")
        pdg_caf = tree["true_pdg"].array(library="np")
        ppfx_w  = tree["ppfx_cv_weight"].array(library="np")

    mask_numu    = pdg_caf ==  14
    mask_numubar = pdg_caf == -14

    print(f"[CAF] N events total:   {len(enu_caf)}")
    print(f"[CAF] N numu    (14):   {mask_numu.sum()}")
    print(f"[CAF] N numubar (-14):  {mask_numubar.sum()}")

    # ── 2. Read NUISANCE numu ────────────────────────────────────────────────
    h_numu, flux_numu, n_files_numu = _read_nuisflat_enu(nuisance_file_dir, bin_edges)
    print(f"[NUISANCE numu]    {n_files_numu} files, flux integral = {flux_numu:.4e} /cm²")
    print(f"[NUISANCE numu]    N signal events (weighted sum): {h_numu.sum():.2f}")

    # ── 3. Read NUISANCE numubar (optional) ──────────────────────────────────
    if nuisance_file_dir_numubar is not None:
        h_numubar, flux_numubar, n_files_numubar = _read_nuisflat_enu(
            nuisance_file_dir_numubar, bin_edges
        )
        print(f"[NUISANCE numubar] {n_files_numubar} files, flux integral = {flux_numubar:.4e} /cm²")

    # ── 4. Load G4NuMI reweight ───────────────────────────────────────────────
    with uproot.open(flux_file_path) as f:
        g4_hist = f["g4numi_reweight_v03_01-->v03_02/fhc/hnom_numu_weights;1"].to_numpy()
    g4_edges  = g4_hist[1][:-1]
    g4_values = g4_hist[0][:-1]  # drop last bin (0.48 artifact)

    bin_idx_g4 = np.searchsorted(g4_edges, enu_caf[mask_numu], side="right") - 1
    bin_idx_g4 = np.clip(bin_idx_g4, 0, len(g4_values) - 1)
    g4_w = g4_values[bin_idx_g4]

    # ── 5. Histogram CAF split by PDG ────────────────────────────────────────
    h_caf_numu,          _ = np.histogram(enu_caf[mask_numu], bins=bin_edges)
    h_caf_numu_weighted, _ = np.histogram(enu_caf[mask_numu], bins=bin_edges, weights=ppfx_w[mask_numu])
    h_caf_numu_g4,       _ = np.histogram(enu_caf[mask_numu], bins=bin_edges, weights=g4_w)
    h_caf_numubar,       _ = np.histogram(enu_caf[mask_numubar], bins=bin_edges, weights=ppfx_w[mask_numubar])

    h_numu_plot = h_numu / n_files_numu
    if nuisance_file_dir_numubar is not None:
        h_numubar_plot = h_numubar / n_files_numubar

    # ── 6. Normalize ─────────────────────────────────────────────────────────
    if normalize:
        h_caf_numu          = h_caf_numu          / (h_caf_numu.sum()          * bin_widths)
        h_caf_numu_weighted = h_caf_numu_weighted / (h_caf_numu_weighted.sum() * bin_widths)
        h_caf_numu_g4       = h_caf_numu_g4       / (h_caf_numu_g4.sum()       * bin_widths)
        h_caf_numubar       = h_caf_numubar       / (h_caf_numubar.sum()       * bin_widths)
        h_numu_plot         = h_numu_plot          / (h_numu_plot.sum()         * bin_widths)
        if nuisance_file_dir_numubar is not None:
            h_numubar_plot = h_numubar_plot / (h_numubar_plot.sum() * bin_widths)

    # ── 7. Plot ──────────────────────────────────────────────────────────────
    fig_numu, ax_numu = plt.subplots(figsize=figsize)

    ax_numu.step(bin_edges, np.append(h_caf_numu, h_caf_numu[-1]),
                 where="post", label=label_caf_numu, linewidth=1.8, color='C0')
    ax_numu.step(bin_edges, np.append(h_caf_numu_weighted, h_caf_numu_weighted[-1]),
                 where="post", label=r"Signal Tree PPFX ($\nu_\mu$)", linewidth=1.8, color='C0', linestyle='--')
    ax_numu.step(bin_edges, np.append(h_caf_numu_g4, h_caf_numu_g4[-1]),
                 where="post", label=r"Signal Tree G4NuMI v03 ($\nu_\mu$)", linewidth=1.8, color='C2', linestyle=':')
    ax_numu.step(bin_edges, np.append(h_numu_plot, h_numu_plot[-1]),
                 where="post", label=label_numu, linewidth=1.8, color='C1')

    ax_numu.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]", fontsize=13)
    ax_numu.set_xlim(bin_edges[0], bin_edges[-1])
    ax_numu.set_ylim(bottom=0)
    ax_numu.legend(fontsize=11)

    if nuisance_file_dir_numubar is not None:
        fig_numubar, ax_numubar = plt.subplots(figsize=figsize)

        ax_numubar.step(bin_edges, np.append(h_caf_numubar, h_caf_numubar[-1]),
                        where="post", label=label_caf_numubar, linewidth=1.8, color='C0')
        ax_numubar.step(bin_edges, np.append(h_numubar_plot, h_numubar_plot[-1]),
                        where="post", label=label_numubar, linewidth=1.8, color='C1')

        ax_numubar.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]", fontsize=13)
        ax_numubar.set_xlim(bin_edges[0], bin_edges[-1])
        ax_numubar.set_ylim(bottom=0)
        ax_numubar.legend(fontsize=11)

        return fig_numu, ax_numu, fig_numubar, ax_numubar

    return fig_numu, ax_numu

# %%
fig_numu, ax_numu, fig_numubar, ax_numubar = compare_enu_caf_vs_nuisance(
    caf_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    nuisance_file_dir="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    flux_file_path = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/2025-04-08_out_450.37_7991.98_79512.66.root",
    normalize=False
)
plt.show()
# Out:
# [CAF] N events total:   24109
# [CAF] N numu    (14):   22670
# [CAF] N numubar (-14):  1439
# [NUISANCE] N total events:  10000000
# [NUISANCE] N signal events: 4904451
# [NUISANCE numu]    10 files, flux integral = 4.6163e-10 /cm²
# [NUISANCE numu]    N signal events (weighted sum): 0.00
# [NUISANCE] N total events:  10000000
# [NUISANCE] N signal events: 2048777
# [NUISANCE numubar] 10 files, flux integral = 2.6999e-10 /cm²
