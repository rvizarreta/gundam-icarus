# %%
from src.plot_scatter import plot_scatter
from src.plot_manual_cross_section import overlay_manual_cross_section
from src.plot_fit_constraints import plot_fit_constraints

# %%
fig_xs, ax_xs = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/XSection/XSec_dpT.root',
        is_cross_section = True,
        hist_path="calcXsec/histograms/True_dpT_XS_TH1D;1",
        xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
        ylabel=r'$\frac{d\sigma}{d\delta p_T}$ $\left[\frac{cm^2}{(GeV/c)Ar}\right]$ $\times 10^{-37}$',
        bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
        is_y_errors = False,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label="GUNDAM Asimov Extraction",
        output_name='Plots/TrueDeltaPT_XS.png',
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        scaling_power_of_10=1e40
)

# %%
bins_mev = [(0, 80), (80, 160), (160, 240), (240, 320), (320, 520), (520, 800), (800, 1000)]
# Overlay manual calculation
fig, ax, xs = overlay_manual_cross_section(
    fig=fig_xs,
    ax=ax_xs,
    signal_tree_path="events/full/selected",
    root_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    bins_mev=bins_mev,
    n_targets=4.6079073e30,
    flux=1.075491e+11,
    color='green',
    marker='s',
    label=r'Signal Histogram Divided by Bin-Width, Flux, and $N_{Target}$',
    variable_name="true_dpT",
    scaling_power_of_10=1e37,
    energy_conversion=True
)
fig.savefig('Plots/TrueDeltaPT_XS_Asimov.png', dpi=300, bbox_inches='tight')
display(fig)
# Out:
# ...
# Signal Events and Cross-Section per True Bin
# ...
# Bin Range (MeV/c)         N_Signal     Bin Width (MeV)    σ (x10^-37 cm²/GeV)
# ------------------------------------------------------------------------------------------
#      0 - 80     MeV/c    2440         80                 6.154451e-01
#     80 - 160    MeV/c    4371         80                 1.102504e+00
#    160 - 240    MeV/c    3833         80                 9.668037e-01
#    240 - 320    MeV/c    2293         80                 5.783671e-01
#    320 - 520    MeV/c    3526         200                3.557475e-01
#    520 - 800    MeV/c    2094         280                1.509066e-01
#    800 - 1000   MeV/c    464          200                4.681419e-02
# ------------------------------------------------------------------------------------------
# Total                     19021
# ...

# %%
fig_template, ax_template = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root',
        is_cross_section = False,
        hist_path="FitterEngine/postFit/Hesse/errors/Template Parameter true_dpT/values/postFitErrors_TH1D;1",
        xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
        ylabel='$\mathbf{Template\ Parameter\ Value\ Post-fit}$',
        bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label=None,
        output_name='Plots/TemplateParameter_TrueDeltaPT.png',
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT'
)

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root",
    figsize=(7, 10),
    directory_path="FitterEngine/postFit/Hesse/errors/Cross section Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
    output_name='Plots/Asimov_fit_constraints_dpT.png'
)
# Out:
# Number of parameters: 52
# Plot saved to: Plots/Asimov_fit_constraints_dpT.png

# %%
fig_xs, ax_xs = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/XSection/XSec_dalphaT.root',
        is_cross_section = True,
        hist_path="calcXsec/histograms/True_dalphaT_XS_TH1D;1",
        xlabel=r'$\mathbf{True}\ \delta \alpha_T\ \mathbf{[deg]}$',
        ylabel=r'$\frac{d\sigma}{d\delta \alpha_T}$ $\left[\frac{cm^2}{(degree)Ar}\right]$ $\times 10^{-40}$',
        bin_edges_labels=[0.0, 30.0, 60.0, 90.0, 120.0, 150.0, 180.0],
        is_y_errors = False,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label="GUNDAM Asimov Extraction",
        output_name='Plots/TrueDalphaT_XS.png',
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        remove_last_bin=False,
        scaling_power_of_10=1e40,
)

# %%
bins_mev = [(0, 30), (30, 60), (60, 90), (90, 120), (120, 150), (150, 180)]
# Overlay manual calculation
fig, ax, xs = overlay_manual_cross_section(
    fig=fig_xs,
    ax=ax_xs,
    signal_tree_path="events/full/selected",
    root_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    bins_mev=bins_mev,
    n_targets=4.6079073e30,
    flux=1.075491e+11,
    color='green',
    marker='s',
    label=r'Signal Histogram Divided by Bin-Width, Flux, and $N_{Target}$',
    variable_name="true_dalphaT_deg",
    scaling_power_of_10=1e37,
    energy_conversion=False
)
fig.savefig('Plots/TrueDeltaAlphaT_XS_Asimov.png', dpi=300, bbox_inches='tight')
display(fig)
# Out:
# ...
# Signal Events and Cross-Section per True Bin
# ...
# Bin Range (MeV/c)         N_Signal     Bin Width (MeV)    σ (x10^-40 cm²/GeV)
# ------------------------------------------------------------------------------------------
#      0 - 30     MeV/c    2177         30                 1.464289e+00
#     30 - 60     MeV/c    2225         30                 1.496574e+00
#     60 - 90     MeV/c    2634         30                 1.771675e+00
#     90 - 120    MeV/c    3187         30                 2.143632e+00
#    120 - 150    MeV/c    4339         30                 2.918488e+00
#    150 - 180    MeV/c    4667         30                 3.139106e+00
# ------------------------------------------------------------------------------------------
# Total                     19229
# ...

# %%
fig_template, ax_template = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dalphaT.root',
        is_cross_section = False,
        hist_path="FitterEngine/postFit/Hesse/errors/Template Parameter true_dalphaT_deg/values/postFitErrors_TH1D;1",
        xlabel=r'$\mathbf{True}\ \delta \alpha_T\ \mathbf{[deg]}$',
        ylabel='$\mathbf{Template\ Parameter\ Value\ Post-fit}$',
        bin_edges_labels=[0.0, 30.0, 60.0, 90.0, 120.0, 150.0, 180.0],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label=None,
        output_name='Plots/TemplateParameter_TrueDAlphaT.png',
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        remove_last_bin=False
)

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dalphaT.root",
    figsize=(7, 10),
    directory_path="FitterEngine/postFit/Hesse/errors/Cross section Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
    output_name='Plots/Asimov_fit_constraints_dalphaT.png'
)
# Out:
# Number of parameters: 52
# Plot saved to: Plots/Asimov_fit_constraints_dalphaT.png

# %%
import uproot
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np

file = uproot.open('/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root')

# ROOT color codes to matplotlib hex colors
root_to_mpl = {
    418: '#1a7000',  # kGreen+2 (dark green)
    416: '#00a000',  # kGreen (lighter green)
    807: '#ff9933',  # kOrange+7 (orange)
    632: '#cc0000',  # kRed (red)
    797: '#cc6600',  # kOrange-3 (brown)
    880: '#9966cc',  # kViolet (purple)
    1: '#000000',    # kBlack (black)
}

# Category configuration matching your YAML
# Format: {interaction_type: (label, color_code)}
categories = {
    0: ('Signal', 418),      # Signal (dark green)
    3: ('Signal', 418),      # Signal (dark green)
    1: ('Signal', 416),      # Signal (light green)
    4: ('Signal', 416),      # Signal (light green)
    6: ('Other CC', 807),    # Other CC (orange)
    7: ('Other CC', 807),    # Other CC (orange)
    8: ('Other CC', 807),    # Other CC (orange)
    9: (r'$\nu$ NC', 632),   # ν NC (red)
    2: ('OOFV', 797),        # OOFV (brown)
    5: ('OOFV', 797),        # OOFV (brown)
    10: ('Cosmic', 880),     # Cosmic (purple)
}

# Stacking order (backgrounds first, signal last)
stack_order = [10, 2, 5, 9, 6, 7, 8, 1, 4, 0, 3]

# Storage for histograms
hist_data = {}
bin_edges = None

# Read all category histograms
print("Reading histograms...")
for cat_type in categories.keys():
    path = f"FitterEngine/preFit/plots/histograms/signal_dpT/reco_dpT/category/{cat_type}/MC_TH1D"
    try:
        hist = file[path]
        values, edges = hist.to_numpy()

        if bin_edges is None:
            bin_edges = edges

        label, color_code = categories[cat_type]
        hist_data[cat_type] = {
            'values': values,
            'label': label,
            'color': root_to_mpl[color_code]
        }
        print(f"  Category {cat_type} ({label}): {values.sum():.1f} events")

    except KeyError:
        print(f"  Category {cat_type}: NOT FOUND")

# Create the plot
fig, ax = plt.subplots(figsize=(10, 7))

# Prepare data for stacking
# Group by unique (label, color) combinations
unique_categories = {}
for cat_type in stack_order:
    if cat_type not in hist_data:
        continue

    label = hist_data[cat_type]['label']
    color = hist_data[cat_type]['color']
    key = (label, color)

    if key not in unique_categories:
        unique_categories[key] = np.zeros_like(hist_data[cat_type]['values'])

    unique_categories[key] += hist_data[cat_type]['values']

# Plot stacked histogram
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
cumulative = np.zeros_like(list(unique_categories.values())[0])

for (label, color), values in unique_categories.items():
    ax.fill_between(
        bin_edges[:-1],
        cumulative,
        cumulative + values,
        step='post',
        label=label,
        color=color,
        alpha=0.8,
        linewidth=0
    )
    # Add edge to last bin
    ax.fill_between(
        [bin_edges[-2], bin_edges[-1]],
        [cumulative[-1], cumulative[-1]],
        [cumulative[-1] + values[-1], cumulative[-1] + values[-1]],
        color=color,
        alpha=0.8,
        linewidth=0
    )
    cumulative += values

# Read and overlay data
try:
    data_hist = file["FitterEngine/preFit/plots/histograms/signal_dpT/reco_dpT/Data_TH1D"]
    data_values, data_edges = data_hist.to_numpy()
    data_errors = np.sqrt(data_values)

    # Plot data as points with error bars
    data_centers = (data_edges[:-1] + data_edges[1:]) / 2
    ax.errorbar(
        data_centers,
        data_values,
        yerr=data_errors,
        fmt='o',
        color='black',
        markersize=6,
        label='Data',
        linewidth=1.5,
        capsize=3
    )
    print(f"\nData: {data_values.sum():.1f} events")

except KeyError:
    print("\nData histogram not found")

# Styling
ax.set_xlabel(r'$\Delta p_T$ [GeV/c]', fontsize=14)
ax.set_ylabel('Events', fontsize=14)
ax.set_xlim(bin_edges[0], bin_edges[-1])
ax.set_ylim(0, ax.get_ylim()[1] * 1.2)  # Add 20% headroom

# Legend (reverse order so signal at top)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], loc='upper right', fontsize=11, framealpha=0.9)

ax.set_title('ICARUS CC0π: Pre-Fit', fontsize=15, pad=10)
ax.grid(True, alpha=0.3, linestyle='--')

plt.show()

# Print summary
print("\n" + "="*70)
print("SUMMARY:")
print("="*70)
total_mc = sum(values.sum() for values in unique_categories.values())
print(f"Total MC: {total_mc:.1f} events")
try:
    print(f"Total Data: {data_values.sum():.1f} events")
    print(f"Data/MC ratio: {data_values.sum()/total_mc:.3f}")
except:
    pass
# Out:
# Reading histograms...
#   Category 0 (Signal): 53.4 events
#   Category 3 (Signal): 85.3 events
#   Category 1 (Signal): 209.5 events
#   Category 4 (Signal): 21.2 events
#   Category 6 (Other CC): 27.8 events
#   Category 7 (Other CC): 1.7 events
#   Category 8 (Other CC): 4.8 events
#   Category 9 ($\nu$ NC): 7.8 events
#   Category 2 (OOFV): 4.0 events
#   Category 5 (OOFV): 1.5 events
#   Category 10: NOT FOUND
#
# Data: 417.2 events
# ...
# SUMMARY:
# ...
# Total MC: 417.2 events
# Total Data: 417.2 events
# Data/MC ratio: 1.000

# %%
import uproot
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np

file = uproot.open('/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dpT.root')

# ROOT color codes to matplotlib hex colors
root_to_mpl = {
    418: '#1a7000',  # kGreen+2 (dark green)
    416: '#00a000',  # kGreen (lighter green)
    807: '#ff9933',  # kOrange+7 (orange)
    632: '#cc0000',  # kRed (red)
    797: '#cc6600',  # kOrange-3 (brown)
    880: '#9966cc',  # kViolet (purple)
    1: '#000000',    # kBlack (black)
}

# Category configuration matching your YAML
# Format: {interaction_type: (label, color_code)}
categories = {
    0: ('Signal', 418),      # Signal (dark green)
    3: ('Signal', 418),      # Signal (dark green)
    1: ('Signal', 416),      # Signal (light green)
    4: ('Signal', 416),      # Signal (light green)
    6: ('Other CC', 807),    # Other CC (orange)
    7: ('Other CC', 807),    # Other CC (orange)
    8: ('Other CC', 807),    # Other CC (orange)
    9: (r'$\nu$ NC', 632),   # ν NC (red)
    2: ('OOFV', 797),        # OOFV (brown)
    5: ('OOFV', 797),        # OOFV (brown)
    10: ('Cosmic', 880),     # Cosmic (purple)
}

# Stacking order (backgrounds first, signal last)
stack_order = [10, 2, 5, 9, 6, 7, 8, 1, 4, 0, 3]

# Storage for histograms
hist_data = {}
bin_edges = None

# Read all category histograms
print("Reading histograms...")
for cat_type in categories.keys():
    path = f"FitterEngine/postFit/samples/histograms/signal_dpT/reco_dpT/category/{cat_type}/MC_TH1D"
    try:
        hist = file[path]
        values, edges = hist.to_numpy()

        if bin_edges is None:
            bin_edges = edges

        label, color_code = categories[cat_type]
        hist_data[cat_type] = {
            'values': values,
            'label': label,
            'color': root_to_mpl[color_code]
        }
        print(f"  Category {cat_type} ({label}): {values.sum():.1f} events")

    except KeyError:
        print(f"  Category {cat_type}: NOT FOUND")

# Create the plot
fig, ax = plt.subplots(figsize=(10, 7))

# Prepare data for stacking
# Group by unique (label, color) combinations
unique_categories = {}
for cat_type in stack_order:
    if cat_type not in hist_data:
        continue

    label = hist_data[cat_type]['label']
    color = hist_data[cat_type]['color']
    key = (label, color)

    if key not in unique_categories:
        unique_categories[key] = np.zeros_like(hist_data[cat_type]['values'])

    unique_categories[key] += hist_data[cat_type]['values']

# Plot stacked histogram
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
cumulative = np.zeros_like(list(unique_categories.values())[0])

for (label, color), values in unique_categories.items():
    ax.fill_between(
        bin_edges[:-1],
        cumulative,
        cumulative + values,
        step='post',
        label=label,
        color=color,
        alpha=0.8,
        linewidth=0
    )
    # Add edge to last bin
    ax.fill_between(
        [bin_edges[-2], bin_edges[-1]],
        [cumulative[-1], cumulative[-1]],
        [cumulative[-1] + values[-1], cumulative[-1] + values[-1]],
        color=color,
        alpha=0.8,
        linewidth=0
    )
    cumulative += values

# Read and overlay data
try:
    data_hist = file["FitterEngine/preFit/plots/histograms/signal_dpT/reco_dpT/Data_TH1D"]
    data_values, data_edges = data_hist.to_numpy()
    data_errors = np.sqrt(data_values)

    # Plot data as points with error bars
    data_centers = (data_edges[:-1] + data_edges[1:]) / 2
    ax.errorbar(
        data_centers,
        data_values,
        yerr=data_errors,
        fmt='o',
        color='black',
        markersize=6,
        label='Data',
        linewidth=1.5,
        capsize=3
    )
    print(f"\nData: {data_values.sum():.1f} events")

except KeyError:
    print("\nData histogram not found")

# Styling
ax.set_xlabel(r'$\Delta p_T$ [GeV/c]', fontsize=14)
ax.set_ylabel('Events', fontsize=14)
ax.set_xlim(bin_edges[0], bin_edges[-1])
ax.set_ylim(0, ax.get_ylim()[1] * 1.2)  # Add 20% headroom

# Legend (reverse order so signal at top)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], loc='upper right', fontsize=11, framealpha=0.9)

ax.set_title('ICARUS CC0π: Pre-Fit', fontsize=15, pad=10)
ax.grid(True, alpha=0.3, linestyle='--')

plt.show()

# Print summary
print("\n" + "="*70)
print("SUMMARY:")
print("="*70)
total_mc = sum(values.sum() for values in unique_categories.values())
print(f"Total MC: {total_mc:.1f} events")
try:
    print(f"Total Data: {data_values.sum():.1f} events")
    print(f"Data/MC ratio: {data_values.sum()/total_mc:.3f}")
except:
    pass
# Out:
# Reading histograms...
#   Category 0 (Signal): 53.4 events
#   Category 3 (Signal): 85.3 events
#   Category 1 (Signal): 209.5 events
#   Category 4 (Signal): 21.2 events
#   Category 6 (Other CC): 27.8 events
#   Category 7 (Other CC): 1.7 events
#   Category 8 (Other CC): 4.8 events
#   Category 9 ($\nu$ NC): 7.8 events
#   Category 2 (OOFV): 4.0 events
#   Category 5 (OOFV): 1.5 events
#   Category 10: NOT FOUND
#
# Data: 417.2 events
# ...
# SUMMARY:
# ...
# Total MC: 417.2 events
# Total Data: 417.2 events
# Data/MC ratio: 1.000
