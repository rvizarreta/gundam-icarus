# %%
try:
    from src.save_fig import save_fig
except ImportError:
    import sys, os
    sys.path.append(os.path.abspath('..'))
    from src.save_fig import save_fig

import sys
import os
sys.path.append(os.path.abspath(".."))
from src.plot_scatter import plot_scatter
from src.plot_manual_cross_section import overlay_manual_cross_section
from src.plot_fit_constraints import plot_fit_constraints
from src.plot_gundam_stacked import plot_gundam_stacked
from src.plot_GENIE_NUISANCE import overlay_genie_nuisance_xsec
from src.plot_matrices import plot_both_matrices

# %%
# Pre-fit plot
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/prefit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root',
    sample_name='selection_reco_dpT',
    variable_name='reco_dpT_lp',
    cov_bin_range=(0, 12), # Covariance matrix elm, cont all range (overflow bin inclusive)
    fit_type='pre-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Prefit' + '\n' + 'Work-in-Progress',
    save_dir=r'../Plots/dpT/Asimov/Prefits', save_name='prefit_dpT',
    pot=r'NuMI MC 7.18 $\times 10^{20}$ POT',
)

# Post-fit plot with custom settings
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/postfit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root',
    sample_name='selection_reco_dpT',
    variable_name='reco_dpT_lp',
    cov_bin_range=(0, 12), # Covariance matrix elm, cont all range (overflow bin inclusive)
    fit_type='post-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Postfit' + '\n' + 'Work-in-Progress',
    pot=r'NuMI MC 7.18 $\times 10^{20}$ POT',
    save_dir=r'../Plots/dpT/Asimov/Postfits', save_name='postfit_dpT'
)

# %%
# Pre-fit plot
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/prefit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root',
    sample_name='sideband_reco_dpT',
    variable_name='reco_dpT_lp',
    cov_bin_range=(13, 37), # Covariance matrix elm -- 25 = 24 finite (binning_reco_dpT_sideband.txt) + 1 overflow bin
    fit_type='pre-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Prefit' + '\n' + 'Work-in-Progress',
    save_dir=r'../Plots/dpT/Asimov/Prefits', save_name='prefit_dpT_sideband',
    pot=r'NuMI MC 7.18 $\times 10^{20}$ POT',
)

# Post-fit plot with custom settings
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/postfit_asimov_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root',
    sample_name='sideband_reco_dpT',
    variable_name='reco_dpT_lp',
    cov_bin_range=(13, 37), # Covariance matrix elm -- 25 = 24 finite (binning_reco_dpT_sideband.txt) + 1 overflow bin
    fit_type='post-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Asimov Postfit' + '\n' + 'Work-in-Progress',
    pot=r'NuMI MC 7.18 $\times 10^{20}$ POT',
    save_dir=r'../Plots/dpT/Asimov/Postfits', save_name='postfit_dpT_sideband'
)

# %%
# Create the scatter plot and get the raw values
fig_xs, ax_xs, xsec_extracted_raw, xsec_extracted_errors_raw = plot_scatter(
    filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/XSection/dpT/Asimov/asimov_XSec_dpT.root',
    is_cross_section=True,
    hist_path="calcXsec/histograms/True_dpT_XS_TH1D;1",
    xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
    ylabel=r'$\frac{d\sigma}{d\delta p_T}$ $\left[\frac{cm^2}{(GeV/c)Ar}\right]$ $\times 10^{-37}$',
    bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
    is_y_errors=True,
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
    label="GUNDAM Asimov Extraction",
    pot=r'NuMI MC 7.18 $\times 10^{20}$ POT',
    scaling_power_of_10=1e40
)

save_fig(fig_xs, r'../Plots/dpT/Asimov/XSection', 'dpT_XS')

# %%
bins_mev = [(0, 80), (80, 160), (160, 240), (240, 320), (320, 520), (520, 800), (800, 1000)]
# Overlay manual calculation
fig, ax, xs = overlay_manual_cross_section(
    fig=fig_xs,
    ax=ax_xs,
    signal_tree_path="events/full/signal",
    root_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    bins_mev=bins_mev,
    n_targets=4.721444e30,#*(1/1.0909),
    flux=5.251614e11, #5.695865e+11, #old flux = 1.076331e+11 for POT = 1.47e20 (old), 7.78521e+20 (new POT). Ideal: 5.175818e+11 (7.0744e20 POT)
    color='green',
    marker='s',
    label=r'Signal Histogram Divided by Bin-Width, Flux, and $N_{Target}$',
    variable_name="true_dpT_lp_genie",
    scaling_power_of_10=1e37,
    energy_conversion=True
)
save_fig(fig, r'../Plots/dpT/Asimov/XSection', 'dpT_XS_wSignal')
display(fig)
# Out:
# ...
# Signal Events and Cross-Section per True Bin
# ...
# Bin Range (MeV/c)         N_Signal     Bin Width (MeV)    σ (x10^-37 cm²/GeV)
# ------------------------------------------------------------------------------------------
#      0 - 80     MeV/c    13855        80                 6.593370e-01
#     80 - 160    MeV/c    24328        80                 1.157757e+00
#    160 - 240    MeV/c    21178        80                 1.007916e+00
#    240 - 320    MeV/c    11969        80                 5.699619e-01
#    320 - 520    MeV/c    21093        200                4.026130e-01
#    520 - 800    MeV/c    15400        280                2.107767e-01
#    800 - 1000   MeV/c    4101         200                7.899151e-02
# ------------------------------------------------------------------------------------------
# Total                     111924
# ...

# %%
# Overlay GENIE with chi2
# Scale to 1e37 for GENIE comparison (no file re-opening needed)
xsec_extracted = xsec_extracted_raw * 1e40
xsec_extracted_errors = xsec_extracted_errors_raw * 1e40

fig_genie, ax_genie, xsec_genie, chi2_info = overlay_genie_nuisance_xsec(
    fig_xs, ax_xs,
    nuisance_file_dir="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/GENIE/fhc_Nu14",
    nuisance_file_dir_numubar="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/GENIE/fhc_Nu-14",
    bin_edges=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.80],
    nuisance_var='ICARUS_1muNp0pi_deltaPT',
    scaling_power_of_10=1e37,
    label='GENIE AR23_20i',
    extracted_xsec=xsec_extracted,
    extracted_xsec_errors=xsec_extracted_errors,
    add_ratio=True,
    draw_extracted_ratio=False,
)

save_fig(fig_genie, r'../Plots/dpT/Asimov/XSection', 'dpT_XS_wGENIE')
display(fig_genie)
# Out:
# ...
# GENIE NUISANCE Cross-Section (ICARUS_1muNp0pi_deltaPT)
# ...
# Bin range                                 xsec
# ----------------------------------------------------------------------
#   0.0000 – 0.0800           6.650366e-01
#   0.0800 – 0.1600           1.177104e+00
#   0.1600 – 0.2400           1.021996e+00
#   0.2400 – 0.3200           5.790883e-01
#   0.3200 – 0.5200           4.070170e-01
#   0.5200 – 0.8000           2.123250e-01
# ...
#
# χ² / Ndof = 0.2 / 6 = 0.028
# p-value = 1.000

# %%
fig_template, ax_template, dummy, dummy2 = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root',
        is_cross_section = False,
        hist_path="FitterEngine/postFit/Hesse/errors/Template Parameter true_dpT_lp_genie/values/postFitErrors_TH1D;1",
        xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
        ylabel='$\mathbf{Template\ Parameter\ Value\ Post-fit}$',
        bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label=None,
        hline_nuisance=True,
        pot=r'NuMI MC 7.18 $\times 10^{20}$ POT'
)
save_fig(fig_template, r'../Plots/dpT/Asimov/TemplateParameters', 'dpT')

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root",
    figsize=(7, 10),
    y_label=r'$\mathbf{Interaction\ Model\ Parameter}$',
    directory_path="FitterEngine/postFit/Hesse/errors/Cross section Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress'
)
save_fig(fig, r'../Plots/dpT/Asimov/NuisanceParameters', 'dpT_InteractionModel')
# Out:
# Number of parameters: 52

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root",
    figsize=(7, 5),
    y_label=r'$\mathbf{Flux\ Parameter}$',
    directory_path="FitterEngine/postFit/Hesse/errors/Multisigma Flux Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress'
)
save_fig(fig, r'../Plots/dpT/Asimov/NuisanceParameters', 'dpT_Flux')
# Out:
# Number of parameters: 27

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/asimov_dpT.root",
    figsize=(7, 3),
    y_label=r'$\mathbf{Detector\ Parameter}$',
    directory_path="FitterEngine/postFit/Hesse/errors/Detector Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress'
)
save_fig(fig, r'../Plots/dpT/Asimov/NuisanceParameters', 'dpT_Detector')
# Out:
# Number of parameters: 9

# %%
BASE = "FitterEngine/postFit/Hesse/errors"
(fig_cov, ax_cov), (fig_corr, ax_corr) = plot_both_matrices(
    '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/Asimov_dpT.root',
    figsize=(8, 20),
    label_name=r"$\mathbf{Interaction\ Model\ Parameter}$",
    cov_path  = f"{BASE}/Cross section Systematics;1/matrices/Covariance_TH2D;1",
    corr_path = f"{BASE}/Cross section Systematics;1/matrices/Correlation_TH2D;1",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
    annotate=True,
)
save_fig(fig_cov, r'/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/Asimov/Postfits', 'xsec_param_covariance')
save_fig(fig_corr, r'/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/Asimov/Postfits', 'xsec_param_correlation')
# Out:
# Full matrix size: 52×52

# %%
BASE = "FitterEngine/postFit/Hesse/errors"
(fig_cov, ax_cov), (fig_corr, ax_corr) = plot_both_matrices(
    '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/Asimov_dpT.root',
    figsize=(6, 15),
    label_name=r"$\mathbf{Flux\ Parameter}$",
    cov_path  = f"{BASE}/Multisigma Flux Systematics;1/matrices/Covariance_TH2D;1",
    corr_path = f"{BASE}/Multisigma Flux Systematics;1/matrices/Correlation_TH2D;1",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
    annotate=True,
)
save_fig(fig_cov, r'/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/Asimov/Postfits', 'flux_param_covariance')
save_fig(fig_corr, r'/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/Asimov/Postfits', 'flux_param_correlation')
# Out:
# Full matrix size: 27×27

# %%
BASE = "FitterEngine/postFit/Hesse/errors"
(fig_cov, ax_cov), (fig_corr, ax_corr) = plot_both_matrices(
    '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/Asimov/Asimov_dpT.root',
    figsize=(5, 15),
    label_name=r"$\mathbf{Detector\ Parameter}$",
    cov_path  = f"{BASE}/Detector Systematics;1/matrices/Covariance_TH2D;1",
    corr_path = f"{BASE}/Detector Systematics;1/matrices/Correlation_TH2D;1",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
    annotate=True,
)
save_fig(fig_cov, r'/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/Asimov/Postfits', 'detector_param_covariance')
save_fig(fig_corr, r'/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/Asimov/Postfits', 'detector_param_correlation')
# Out:
# Full matrix size: 9×9

# %%
fig_xs, ax_xs = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/XSection/XSec_dalphaT.root',
        is_cross_section = True,
        hist_path="calcXsec/histograms/True_dalphaT_XS_TH1D;1",
        xlabel=r'$\mathbf{True}\ \delta \alpha_T\ \mathbf{[deg]}$',
        ylabel=r'$\frac{d\sigma}{d\delta \alpha_T}$ $\left[\frac{cm^2}{(degree)Ar}\right]$ $\times 10^{-40}$',
        bin_edges_labels=[0.0, 30.0, 60.0, 90.0, 120.0, 150.0, 180.0],
        is_y_errors = False,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label="GUNDAM Asimov Extraction",
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        remove_last_bin=False,
        scaling_power_of_10=1e40,
)
save_fig(fig_xs, r'Plots/Asimov/XSection', 'dalphaT_XS')

# %%
bins_mev = [(0, 30), (30, 60), (60, 90), (90, 120), (120, 150), (150, 180)]
# Overlay manual calculation
fig, ax, xs = overlay_manual_cross_section(
    fig=fig_xs,
    ax=ax_xs,
    signal_tree_path="events/full/signal",
    root_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    bins_mev=bins_mev,
    n_targets=4.6079073e30,
    flux=1.075491e+11,
    color='green',
    marker='s',
    label=r'Signal Histogram Divided by Bin-Width, Flux, and $N_{Target}$',
    variable_name="true_dalphaT_deg",
    scaling_power_of_10=1e37,
    energy_conversion=False
)
save_fig(fig, r'Plots/Asimov/XSection', 'dalphaT_XS_wSignal')
display(fig)

# %%
fig_template, ax_template = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dalphaT.root',
        is_cross_section = False,
        hist_path="FitterEngine/postFit/Hesse/errors/Template Parameter true_dalphaT_deg/values/postFitErrors_TH1D;1",
        xlabel=r'$\mathbf{True}\ \delta \alpha_T\ \mathbf{[deg]}$',
        ylabel='$\mathbf{Template\ Parameter\ Value\ Post-fit}$',
        bin_edges_labels=[0.0, 30.0, 60.0, 90.0, 120.0, 150.0, 180.0],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress',
        label=None,
        pot=r'NuMI MC 1.47 $\times 10^{20}$ POT',
        remove_last_bin=False
)
save_fig(fig_template, r'Plots/Asimov/TemplateParameters', 'dalphaT')

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Asimov/asimov_dalphaT.root",
    figsize=(7, 10),
    directory_path="FitterEngine/postFit/Hesse/errors/Cross section Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Asimov' + '\n' + 'Work-in-Progress'
)
save_fig(fig, r'Plots/Asimov/NuisanceParameters', 'dalphaT_InteractionModel')

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd


def _read_nuisflat_enu(file_dir, bin_edges, flux_binwidth_divided=True):
    """
    Read all nuisflat files from one directory for Enu comparison.
    Returns (h_weighted, flux_integral, n_files).
    """
    files = sorted(glob.glob(f"{file_dir}/output_GENIE_*.nuisflat.root"))
    if not files:
        raise FileNotFoundError(f'No files found in {file_dir}')

    df_all = None
    flux_integral = None

    for f_path in files:
        with uproot.open(f_path) as f:
            df = f["FlatTree_VARS"].arrays(
                ["Enu_true", "InputWeight", "fScaleFactor", "ICARUS_1muNp0pi_IsSignal"],
                library="pd"
            )
            if df_all is None:
                df_all = df
                flux_hist = f["FlatTree_FLUX"].to_numpy()
                flux_integral = (
                    np.sum(flux_hist[0] * np.diff(flux_hist[1]))
                    if flux_binwidth_divided
                    else np.sum(flux_hist[0])
                )
                flux_integral *= 1e-4  # /m² → /cm²
            else:
                df_all = pd.concat([df_all, df], ignore_index=True)

    df_all["FinalWeight"] = df_all["InputWeight"] * df_all["fScaleFactor"]
    df_all["Enu_true_GeV"] = df_all["Enu_true"] * 1e-3
    df_sig = df_all.query("ICARUS_1muNp0pi_IsSignal == 1")

    h = np.histogram(df_sig["Enu_true_GeV"], bins=bin_edges,
                     weights=df_sig["FinalWeight"])[0]

    print(f"[NUISANCE] N total events:  {len(df_all)}")
    print(f"[NUISANCE] N signal events: {len(df_sig)}")

    return h, flux_integral, len(files)


def compare_enu_caf_vs_nuisance(
    caf_file_path,
    nuisance_file_dir,
    nuisance_file_dir_numubar=None,
    caf_tree_path="events/nominal/signal",
    bin_edges=np.linspace(0, 5, 51),
    normalize=True,
    label_caf_numu=r"Signal Tree ($\nu_\mu$)",
    label_caf_numubar=r"Signal Tree ($\bar{\nu}_\mu$)",
    label_numu=r"GENIE NUISANCE ($\nu_\mu$)",
    label_numubar=r"GENIE NUISANCE ($\bar{\nu}_\mu$)",
    figsize=(7, 6),
):
    bin_edges  = np.array(bin_edges)
    bin_widths = np.diff(bin_edges)

    # ── 1. Read CAF Enu + PDG ────────────────────────────────────────────────
    with uproot.open(caf_file_path) as f:
        tree = f[caf_tree_path]
        enu_caf = tree["true_neutrino_energy"].array(library="np")
        pdg_caf = tree["true_pdg"].array(library="np")
        cat_caf = tree["category"].array(library="np")

    cat_mask = np.isin(cat_caf, [0, 1, 3, 4])
    enu_caf = enu_caf[cat_mask]
    pdg_caf = pdg_caf[cat_mask]

    mask_numu    = pdg_caf ==  14
    mask_numubar = pdg_caf == -14

    print(f"[CAF] N events total:   {len(enu_caf)}")
    print(f"[CAF] N numu    (14):   {mask_numu.sum()}")
    print(f"[CAF] N numubar (-14):  {mask_numubar.sum()}")

    # ── 2. Read NUISANCE numu ────────────────────────────────────────────────
    h_numu, flux_numu, n_files_numu = _read_nuisflat_enu(nuisance_file_dir, bin_edges)
    print(f"[NUISANCE numu]    {n_files_numu} files, flux integral = {flux_numu:.4e} /cm²")
    print(f"[NUISANCE numu]    N signal events (weighted sum): {h_numu.sum():.2f}")

    # ── 3. Read NUISANCE numubar (optional) ──────────────────────────────────
    if nuisance_file_dir_numubar is not None:
        h_numubar, flux_numubar, n_files_numubar = _read_nuisflat_enu(
            nuisance_file_dir_numubar, bin_edges
        )
        print(f"[NUISANCE numubar] {n_files_numubar} files, flux integral = {flux_numubar:.4e} /cm²")

    # ── 4. Histogram CAF split by PDG ────────────────────────────────────────
    h_caf_numu,          _ = np.histogram(enu_caf[mask_numu], bins=bin_edges)
    h_caf_numu_weighted, _ = np.histogram(enu_caf[mask_numu], bins=bin_edges)
    h_caf_numubar,       _ = np.histogram(enu_caf[mask_numubar], bins=bin_edges)

    h_numu_plot = h_numu / n_files_numu
    if nuisance_file_dir_numubar is not None:
        h_numubar_plot = h_numubar / n_files_numubar

    # ── 5. Normalize ─────────────────────────────────────────────────────────
    if normalize:
        h_caf_numu          = h_caf_numu          / (h_caf_numu.sum()          * bin_widths)
        h_caf_numu_weighted = h_caf_numu_weighted / (h_caf_numu_weighted.sum() * bin_widths)
        h_caf_numubar       = h_caf_numubar       / (h_caf_numubar.sum()       * bin_widths)
        h_numu_plot         = h_numu_plot          / (h_numu_plot.sum()         * bin_widths)
        if nuisance_file_dir_numubar is not None:
            h_numubar_plot = h_numubar_plot / (h_numubar_plot.sum() * bin_widths)

    # ── 6. Plot ──────────────────────────────────────────────────────────────
    fig_numu, ax_numu = plt.subplots(figsize=figsize)

    ax_numu.step(bin_edges, np.append(h_caf_numu, h_caf_numu[-1]),
                 where="post", label=label_caf_numu, linewidth=1.8, color='C0')
    ax_numu.step(bin_edges, np.append(h_numu_plot, h_numu_plot[-1]),
                 where="post", label=label_numu, linewidth=1.8, color='C1')

    ax_numu.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]", fontsize=13)
    ax_numu.set_xlim(bin_edges[0], bin_edges[-1])
    ax_numu.set_ylim(bottom=0)
    ax_numu.legend(fontsize=11)

    if nuisance_file_dir_numubar is not None:
        fig_numubar, ax_numubar = plt.subplots(figsize=figsize)

        ax_numubar.step(bin_edges, np.append(h_caf_numubar, h_caf_numubar[-1]),
                        where="post", label=label_caf_numubar, linewidth=1.8, color='C0')
        ax_numubar.step(bin_edges, np.append(h_numubar_plot, h_numubar_plot[-1]),
                        where="post", label=label_numubar, linewidth=1.8, color='C1')

        ax_numubar.set_xlabel(r"$E_\nu^{\rm true}$ [GeV]", fontsize=13)
        ax_numubar.set_xlim(bin_edges[0], bin_edges[-1])
        ax_numubar.set_ylim(bottom=0)
        ax_numubar.legend(fontsize=11)

        return fig_numu, ax_numu, fig_numubar, ax_numubar

    return fig_numu, ax_numu

# %%
fig_numu, ax_numu, fig_numubar, ax_numubar = compare_enu_caf_vs_nuisance(
    caf_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    nuisance_file_dir="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    normalize=True
)
plt.show()

# %%
import numpy as np
def compare_dpt_caf_vs_nuisance(
    caf_file_path,
    nuisance_file_dir,
    nuisance_file_dir_numubar=None,
    caf_tree_path="events/full/signal",
    bin_edges=np.linspace(0, 1, 51),
    normalize=True,
    label_caf_numu=r"Signal Tree ($\nu_\mu$)",
    label_caf_numubar=r"Signal Tree ($\bar{\nu}_\mu$)",
    label_numu=r"GENIE NUISANCE ($\nu_\mu$)",
    label_numubar=r"GENIE NUISANCE ($\bar{\nu}_\mu$)",
    figsize=(7, 6),
):
    bin_edges  = np.array(bin_edges)
    bin_widths = np.diff(bin_edges)

    # ── 1. Read CAF true_dpT + PDG ───────────────────────────────────────────
    with uproot.open(caf_file_path) as f:
        tree = f[caf_tree_path]
        dpt_caf = tree["true_dpT"].array(library="np")
        pdg_caf = tree["true_pdg"].array(library="np")
        cat_caf = tree["category"].array(library="np")

    cat_mask = np.isin(cat_caf, [0, 1, 3, 4])
    dpt_caf = tree["true_dpT"].array(library="np") * 1e-3  # MeV/c → GeV/c
    pdg_caf  = pdg_caf[cat_mask]

    mask_numu    = pdg_caf ==  14
    mask_numubar = pdg_caf == -14

    print(f"[CAF] N events total:   {len(dpt_caf)}")
    print(f"[CAF] N numu    (14):   {mask_numu.sum()}")
    print(f"[CAF] N numubar (-14):  {mask_numubar.sum()}")

    # ── 2. Read NUISANCE numu δpT ────────────────────────────────────────────
    h_numu, n_files_numu = _read_nuisflat_dpt(nuisance_file_dir, bin_edges)
    print(f"[NUISANCE numu]    {n_files_numu} files")
    print(f"[NUISANCE numu]    N signal events (weighted sum): {h_numu.sum():.2f}")

    # ── 3. Read NUISANCE numubar δpT (optional) ──────────────────────────────
    if nuisance_file_dir_numubar is not None:
        h_numubar, n_files_numubar = _read_nuisflat_dpt(nuisance_file_dir_numubar, bin_edges)
        print(f"[NUISANCE numubar] {n_files_numubar} files")

    # ── 4. Histogram CAF split by PDG ────────────────────────────────────────
    h_caf_numu,    _ = np.histogram(dpt_caf[mask_numu],    bins=bin_edges)
    h_caf_numubar, _ = np.histogram(dpt_caf[mask_numubar], bins=bin_edges)

    h_numu_plot = h_numu / n_files_numu
    if nuisance_file_dir_numubar is not None:
        h_numubar_plot = h_numubar / n_files_numubar

    # ── 5. Normalize ─────────────────────────────────────────────────────────
    if normalize:
        h_caf_numu    = h_caf_numu    / (h_caf_numu.sum()    * bin_widths)
        h_caf_numubar = h_caf_numubar / (h_caf_numubar.sum() * bin_widths)
        h_numu_plot   = h_numu_plot   / (h_numu_plot.sum()   * bin_widths)
        if nuisance_file_dir_numubar is not None:
            h_numubar_plot = h_numubar_plot / (h_numubar_plot.sum() * bin_widths)

    # ── 6. Plot ──────────────────────────────────────────────────────────────
    fig_numu, ax_numu = plt.subplots(figsize=figsize)

    ax_numu.step(bin_edges, np.append(h_caf_numu, h_caf_numu[-1]),
                 where="post", label=label_caf_numu, linewidth=1.8, color='C0')
    ax_numu.step(bin_edges, np.append(h_numu_plot, h_numu_plot[-1]),
                 where="post", label=label_numu, linewidth=1.8, color='C1')

    ax_numu.set_xlabel(r"$\delta p_T$ [GeV/c]", fontsize=13)
    ax_numu.set_xlim(bin_edges[0], bin_edges[-1])
    ax_numu.set_ylim(bottom=0)
    ax_numu.legend(fontsize=11)

    if nuisance_file_dir_numubar is not None:
        fig_numubar, ax_numubar = plt.subplots(figsize=figsize)

        ax_numubar.step(bin_edges, np.append(h_caf_numubar, h_caf_numubar[-1]),
                        where="post", label=label_caf_numubar, linewidth=1.8, color='C0')
        ax_numubar.step(bin_edges, np.append(h_numubar_plot, h_numubar_plot[-1]),
                        where="post", label=label_numubar, linewidth=1.8, color='C1')

        ax_numubar.set_xlabel(r"$\delta p_T$ [GeV/c]", fontsize=13)
        ax_numubar.set_xlim(bin_edges[0], bin_edges[-1])
        ax_numubar.set_ylim(bottom=0)
        ax_numubar.legend(fontsize=11)

        return fig_numu, ax_numu, fig_numubar, ax_numubar

    return fig_numu, ax_numu


def _read_nuisflat_dpt(file_dir, bin_edges):
    """
    Read all nuisflat files from one directory for δpT comparison.
    Returns (h_weighted, n_files).
    Note: no flux normalization needed since we're shape-comparing only.
    """
    files = sorted(glob.glob(f"{file_dir}/output_GENIE_*.nuisflat.root"))
    if not files:
        raise FileNotFoundError(f'No files found in {file_dir}')

    df_all = None

    for f_path in files:
        with uproot.open(f_path) as f:
            df = f["FlatTree_VARS"].arrays(
                ["ICARUS_1muNp0pi_deltaPT", "InputWeight", "fScaleFactor",
                 "ICARUS_1muNp0pi_IsSignal"],
                library="pd"
            )
            df_all = df if df_all is None else pd.concat([df_all, df], ignore_index=True)

    df_all["FinalWeight"] = df_all["InputWeight"] * df_all["fScaleFactor"]
    df_sig = df_all.query("ICARUS_1muNp0pi_IsSignal == 1")

    print(f"[NUISANCE] N total events:  {len(df_all)}")
    print(f"[NUISANCE] N signal events: {len(df_sig)}")

    # Convert MeV → GeV if needed (check your NUISANCE output units)
    dpt_vals = df_sig["ICARUS_1muNp0pi_deltaPT"]

    h = np.histogram(dpt_vals, bins=bin_edges, weights=df_sig["FinalWeight"])[0]

    return h, len(files)

# %%
# At the top of your script (same imports you already have)
import uproot
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd

compare_dpt_caf_vs_nuisance(
    caf_file_path="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam.root",
    nuisance_file_dir="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    normalize=True
)
plt.show()

# %%
"""
Extract POT from events/full/POT TH1D — exhaustively.

The earlier attempts failed with 'len() of unsized object' which suggests
fN is a single scalar in some uproot version, or the type interpretation
is unusual. This script tries every plausible extraction path and prints
all the raw members so we can see exactly what's in the histogram.
"""

import uproot
import numpy as np

OLD_PATH = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_oficial.root"
NEW_PATH = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained_systematics.root"


def deep_inspect_pot(path, label):
    print(f"\n{'='*70}")
    print(f"{label}: {path.split('/')[-1]}")
    print('='*70)

    f = uproot.open(path)
    h = f["events/full/POT"]

    print(f"\nObject type: {type(h)}")
    print(f"classname:   {h.classname if hasattr(h, 'classname') else 'n/a'}")

    # Method 1: Print every member with full contents
    print(f"\n--- Method 1: all_members ---")
    members = h.all_members
    for k, v in members.items():
        # Try to print the value robustly
        try:
            if hasattr(v, "__len__"):
                try:
                    length = len(v)
                    if length < 30:
                        print(f"  {k:25s} = {v}   (len={length})")
                    else:
                        arr = np.asarray(v)
                        print(f"  {k:25s} : array of len {length}, "
                              f"sum={arr.sum():.4e}, "
                              f"nonzero={np.count_nonzero(arr)}, "
                              f"first 5: {arr[:5]}")
                except TypeError:
                    print(f"  {k:25s} = {v}   (has __len__ but len() failed)")
            else:
                print(f"  {k:25s} = {v}")
        except Exception as e:
            print(f"  {k:25s} : <error: {e}>")

    # Method 2: Try uproot's high-level histogram interface
    print(f"\n--- Method 2: uproot histogram interface ---")
    try:
        values = h.values()
        print(f"  h.values():        {values}  type={type(values)}, shape={getattr(values, 'shape', 'n/a')}")
        if hasattr(values, "sum"):
            print(f"  h.values().sum():  {values.sum():.4e}")
    except Exception as e:
        print(f"  h.values() failed: {e}")

    try:
        edges = h.axis().edges()
        print(f"  h.axis().edges():  {edges}  shape={getattr(edges, 'shape', 'n/a')}")
    except Exception as e:
        print(f"  h.axis().edges() failed: {e}")

    try:
        np_hist = h.to_numpy()
        print(f"  h.to_numpy():      counts={np_hist[0]}, edges={np_hist[1]}")
        print(f"  counts.sum():      {np.asarray(np_hist[0]).sum():.4e}")
    except Exception as e:
        print(f"  h.to_numpy() failed: {e}")

    try:
        boost_hist = h.to_boost()
        print(f"  h.to_boost():      {boost_hist}")
        print(f"  boost view:        {boost_hist.view()}")
        print(f"  boost sum:         {boost_hist.view().sum():.4e}")
    except Exception as e:
        print(f"  h.to_boost() failed: {e}")

    # Method 3: fEntries × fTsumw arithmetic
    print(f"\n--- Method 3: derived quantities ---")
    fEntries = members.get("fEntries")
    fTsumw   = members.get("fTsumw")
    fTsumw2  = members.get("fTsumw2")
    fTsumwx  = members.get("fTsumwx")
    print(f"  fEntries  = {fEntries}")
    print(f"  fTsumw    = {fTsumw}     (sum of weights — often == POT)")
    print(f"  fTsumw2   = {fTsumw2}    (sum of weights^2)")
    print(f"  fTsumwx   = {fTsumwx}    (sum of w*x)")
    if fEntries and fTsumw:
        print(f"  fTsumw/fEntries = {fTsumw/fEntries:.4e}  (mean weight per entry)")

    # Method 4: Look at fN array carefully
    print(f"\n--- Method 4: fN bin contents inspection ---")
    fN = members.get("fN")
    if fN is None:
        print("  fN is None")
    else:
        print(f"  fN type: {type(fN)}")
        try:
            arr = np.asarray(fN)
            print(f"  asarray shape: {arr.shape}, dtype: {arr.dtype}")
            print(f"  asarray ndim: {arr.ndim}")
            if arr.ndim == 0:
                print(f"  scalar value: {arr.item()}")
            else:
                print(f"  total sum (incl underflow/overflow): {arr.sum():.4e}")
                if len(arr) >= 3:
                    print(f"  underflow (bin 0): {arr[0]}")
                    print(f"  overflow  (bin -1): {arr[-1]}")
                    print(f"  in-range sum:      {arr[1:-1].sum():.4e}")
                if len(arr) <= 20:
                    print(f"  full contents:     {arr}")
                else:
                    print(f"  first 10:          {arr[:10]}")
                    print(f"  last 10:           {arr[-10:]}")
        except Exception as e:
            print(f"  asarray failed: {e}")
            # Try iterating
            try:
                vals = list(fN)
                print(f"  Iterated: len={len(vals)}, first 5: {vals[:5]}")
            except Exception as e2:
                print(f"  Iteration also failed: {e2}")

    # Method 5: Just dump the raw bytes via streamerinfo if all else fails
    print(f"\n--- Method 5: TTree-style read (in case POT is actually a small tree) ---")
    try:
        if hasattr(h, "arrays"):
            arr = h.arrays(library="np")
            print(f"  Got arrays: {arr}")
    except Exception as e:
        print(f"  Not a TTree: {e}")


for path, label in [(OLD_PATH, "OLD MC"), (NEW_PATH, "NEW MC")]:
    deep_inspect_pot(path, label)

# Summary at the end
print(f"\n\n{'='*70}\nSUMMARY\n{'='*70}")
print("Documented POT:")
print(f"  OLD: 1.47115e+20")
print(f"  NEW: 7.78521e+20")
print(f"  ratio NEW/OLD: {7.78521/1.47115:.4f}")
print(f"\nIf the deficit is purely a POT bookkeeping error,")
print(f"  actual NEW POT should be: 7.78521e20 × 0.9167 = {7.78521e20 * 0.9167:.4e}")
print(f"\nLook above at fTsumw or to_numpy().sum() for each file —")
print(f"  if those values match the documented POTs, bookkeeping is correct (deficit is real physics).")
print(f"  if NEW's value is closer to 7.14e20, the documented number is wrong.")

# %%
"""
Plot PPFX CV weight as a function of true neutrino energy,
split by neutrino flavor (numu vs. numubar).

Reads `ppfx_cv_weight`, `true_neutrino_energy`, and `true_pdg` from the
`events/full/selected` tree.

Three rows of three panels:
  Row 1: numu  (pdg == +14)
  Row 2: numubar (pdg == -14)
  Row 3: overlay of the two profiles for direct comparison

Columns are the same as before:
  Col 1: 2D hexbin density
  Col 2: profile (mean per E_nu bin + std band + SEM error bars)
  Col 3: 1D distribution of weights
"""

import os
import numpy as np
import uproot
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# ----------------------------------------------------------------------------
# Configuration
# ----------------------------------------------------------------------------
FILE_PATH = (
    "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/"
    "My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/"
    "ICARUS_CC0pi_Selection/data/"
    "icarus_numi_numu_mc_onbeam_offbeam_syst_gundam_withPCA.root"
)
TREE_PATH = "events/full/selected"

ENU_MIN = 0.0
ENU_MAX = 10.0
N_ENU_BINS = 40

# Write to current directory so it works regardless of machine.
OUTPUT_PNG = os.path.join(os.path.expanduser("~"), "ppfx_vs_enu_by_flavor.png")


# ----------------------------------------------------------------------------
# Load data
# ----------------------------------------------------------------------------
print(f"Opening file: {FILE_PATH}")
f = uproot.open(FILE_PATH)
tree = f[TREE_PATH]

arrs = tree.arrays(
    ["ppfx_cv_weight", "true_neutrino_energy", "true_pdg"],
    library="np",
)
ppfx = arrs["ppfx_cv_weight"]
enu = arrs["true_neutrino_energy"]
pdg = arrs["true_pdg"]

print(f"Loaded {len(ppfx)} events from {TREE_PATH}")

# Physical mask + exclude w=1.0 sentinel (nue/nuebar/no-truth fallback in
# addPPFX_systematics.py). PDG cast to int via np.rint to handle stored floats.
pdg_int = np.rint(pdg).astype(np.int64)
base_mask = (
    np.isfinite(ppfx) & np.isfinite(enu) & (enu > 0)
    & (ppfx > 0) & (ppfx != 1.0)
)
numu_mask    = base_mask & (pdg_int ==  14)
numubar_mask = base_mask & (pdg_int == -14)

print(f"  Total physical entries:     {base_mask.sum()}")
print(f"  numu    (pdg == +14):       {numu_mask.sum()}")
print(f"  numubar (pdg == -14):       {numubar_mask.sum()}")
print(f"  Other (nue/nuebar/etc.):    "
      f"{base_mask.sum() - numu_mask.sum() - numubar_mask.sum()}")


# ----------------------------------------------------------------------------
# Profile builder
# ----------------------------------------------------------------------------
enu_edges = np.linspace(ENU_MIN, ENU_MAX, N_ENU_BINS + 1)
enu_centers = 0.5 * (enu_edges[:-1] + enu_edges[1:])


def build_profile(enu_vals, ppfx_vals):
    """Mean / std / SEM of ppfx in each E_nu bin."""
    bin_idx = np.digitize(enu_vals, enu_edges) - 1
    in_range = (bin_idx >= 0) & (bin_idx < N_ENU_BINS)
    bin_idx = bin_idx[in_range]
    w = ppfx_vals[in_range]

    mean = np.full(N_ENU_BINS, np.nan)
    std = np.full(N_ENU_BINS, np.nan)
    count = np.zeros(N_ENU_BINS, dtype=int)
    for b in range(N_ENU_BINS):
        sel = bin_idx == b
        n = sel.sum()
        count[b] = n
        if n > 0:
            mean[b] = w[sel].mean()
        if n > 1:
            std[b] = w[sel].std()

    with np.errstate(divide="ignore", invalid="ignore"):
        sem = np.where(count > 0, std / np.sqrt(count), np.nan)
    return mean, std, sem, count


def summarize(name, ppfx_vals):
    """Print one-line summary for a flavor subset."""
    if ppfx_vals.size == 0:
        print(f"{name}: no entries")
        return None, None
    m, s = ppfx_vals.mean(), ppfx_vals.std()
    print(f"{name}: N={ppfx_vals.size}, mean={m:.4f}, std={s:.4f} "
          f"({100*s/m:.2f}% of mean), "
          f"range=[{ppfx_vals.min():.4f}, {ppfx_vals.max():.4f}]")
    return m, s


# ----------------------------------------------------------------------------
# Per-flavor data + summary stats
# ----------------------------------------------------------------------------
flavors = {
    "numu":    {"mask": numu_mask,    "color": "steelblue",
                "label": r"$\nu_\mu$"},
    "numubar": {"mask": numubar_mask, "color": "darkorange",
                "label": r"$\bar{\nu}_\mu$"},
}

print()
for key, info in flavors.items():
    m = info["mask"]
    info["enu"] = enu[m]
    info["ppfx"] = ppfx[m]
    info["mean_overall"], info["std_overall"] = summarize(key, info["ppfx"])
    info["prof_mean"], info["prof_std"], info["prof_sem"], info["prof_count"] = (
        build_profile(info["enu"], info["ppfx"])
    )


# ----------------------------------------------------------------------------
# Plot
# ----------------------------------------------------------------------------
fig, axes = plt.subplots(3, 3, figsize=(18, 14))

# --- Row 1 and Row 2: one row per flavor ------------------------------------
for row_idx, (key, info) in enumerate(flavors.items()):
    ax_hex, ax_prof, ax_hist = axes[row_idx]

    enu_v = info["enu"]
    ppfx_v = info["ppfx"]
    color = info["color"]
    label = info["label"]
    mean_overall = info["mean_overall"]
    std_overall = info["std_overall"]

    # Hexbin
    if ppfx_v.size > 0:
        ymin = max(0.5, ppfx_v.min())
        ymax = min(1.5, ppfx_v.max())
        hb = ax_hex.hexbin(
            enu_v, ppfx_v,
            gridsize=60,
            extent=(ENU_MIN, ENU_MAX, ymin, ymax),
            cmap="viridis",
            norm=LogNorm(),
            mincnt=1,
        )
        fig.colorbar(hb, ax=ax_hex, label="events (log scale)")
        ax_hex.axhline(1.0, color="white", linestyle="--",
                       linewidth=1, alpha=0.7, label="w = 1")
        ax_hex.axhline(mean_overall, color="red", linestyle="-",
                       linewidth=1.2, label=f"mean = {mean_overall:.3f}")
        ax_hex.legend(loc="upper right", fontsize=9)
    ax_hex.set_xlabel(r"$E_\nu^{\mathrm{true}}$ [GeV]", fontsize=11,
                      weight="bold")
    ax_hex.set_ylabel(r"$w_{\mathrm{PPFX\ CV}}$", fontsize=11, weight="bold")
    ax_hex.set_title(f"{label}: weight vs. $E_\\nu$  (N = {ppfx_v.size})",
                     fontsize=11)
    ax_hex.grid(alpha=0.3)

    # Profile
    valid = np.isfinite(info["prof_mean"])
    ax_prof.fill_between(
        enu_centers[valid],
        info["prof_mean"][valid] - info["prof_std"][valid],
        info["prof_mean"][valid] + info["prof_std"][valid],
        alpha=0.25, color=color, label=r"mean $\pm$ std (per bin)",
    )
    ax_prof.errorbar(
        enu_centers[valid], info["prof_mean"][valid],
        yerr=info["prof_sem"][valid],
        fmt="o", markersize=4, color=color,
        capsize=2, elinewidth=1, label=r"mean $\pm$ SEM",
    )
    ax_prof.axhline(1.0, color="black", linestyle="--",
                    linewidth=1, alpha=0.5, label="w = 1")
    if mean_overall is not None:
        ax_prof.axhline(mean_overall, color="red", linestyle="-",
                        linewidth=1, label=f"overall mean = {mean_overall:.3f}")
    ax_prof.set_xlabel(r"$E_\nu^{\mathrm{true}}$ [GeV]", fontsize=11,
                       weight="bold")
    ax_prof.set_ylabel(r"$\langle w_{\mathrm{PPFX\ CV}} \rangle$",
                       fontsize=11, weight="bold")
    ax_prof.set_title(f"{label}: profile", fontsize=11)
    ax_prof.legend(loc="best", fontsize=9)
    ax_prof.grid(alpha=0.3)
    ax_prof.set_xlim(ENU_MIN, ENU_MAX)

    # 1D distribution
    if ppfx_v.size > 0:
        ax_hist.hist(
            ppfx_v, bins=80,
            range=(max(0.5, ppfx_v.min()), min(1.5, ppfx_v.max())),
            color=color, alpha=0.7, edgecolor="black", linewidth=0.5,
        )
        ax_hist.axvline(1.0, color="black", linestyle="--",
                        linewidth=1, alpha=0.5, label="w = 1")
        ax_hist.axvline(mean_overall, color="red", linestyle="-",
                        linewidth=1.5, label=f"mean = {mean_overall:.3f}")
        ax_hist.axvline(mean_overall - std_overall, color="red",
                        linestyle=":", linewidth=1,
                        label=fr"$\pm 1\sigma$ = {std_overall:.3f}")
        ax_hist.axvline(mean_overall + std_overall, color="red",
                        linestyle=":", linewidth=1)
        ax_hist.legend(loc="upper right", fontsize=9)
    ax_hist.set_xlabel(r"$w_{\mathrm{PPFX\ CV}}$", fontsize=11, weight="bold")
    ax_hist.set_ylabel("events", fontsize=11, weight="bold")
    ax_hist.set_title(f"{label}: weight distribution", fontsize=11)
    ax_hist.grid(alpha=0.3)


# --- Row 3: overlay panels --------------------------------------------------
ax_overlay_prof = axes[2, 0]
ax_overlay_hist = axes[2, 1]
ax_overlay_ratio = axes[2, 2]

# Overlay of profiles
for key, info in flavors.items():
    valid = np.isfinite(info["prof_mean"])
    color = info["color"]
    label = info["label"]
    ax_overlay_prof.fill_between(
        enu_centers[valid],
        info["prof_mean"][valid] - info["prof_std"][valid],
        info["prof_mean"][valid] + info["prof_std"][valid],
        alpha=0.20, color=color,
    )
    ax_overlay_prof.errorbar(
        enu_centers[valid], info["prof_mean"][valid],
        yerr=info["prof_sem"][valid],
        fmt="o-", markersize=4, color=color,
        capsize=2, elinewidth=1, linewidth=1.2,
        label=f"{label} (mean = {info['mean_overall']:.3f})",
    )
ax_overlay_prof.axhline(1.0, color="black", linestyle="--",
                        linewidth=1, alpha=0.5)
ax_overlay_prof.set_xlabel(r"$E_\nu^{\mathrm{true}}$ [GeV]", fontsize=11,
                           weight="bold")
ax_overlay_prof.set_ylabel(r"$\langle w_{\mathrm{PPFX\ CV}} \rangle$",
                           fontsize=11, weight="bold")
ax_overlay_prof.set_title("Overlay: profile comparison", fontsize=11)
ax_overlay_prof.legend(loc="best", fontsize=10)
ax_overlay_prof.grid(alpha=0.3)
ax_overlay_prof.set_xlim(ENU_MIN, ENU_MAX)

# Overlay of 1D weight distributions (normalized for shape comparison)
for key, info in flavors.items():
    ppfx_v = info["ppfx"]
    if ppfx_v.size == 0:
        continue
    ax_overlay_hist.hist(
        ppfx_v, bins=80,
        range=(0.85, 1.15),
        color=info["color"], alpha=0.5,
        density=True,
        label=f"{info['label']} (N = {ppfx_v.size})",
        edgecolor=info["color"], linewidth=1.0,
    )
ax_overlay_hist.axvline(1.0, color="black", linestyle="--",
                        linewidth=1, alpha=0.5, label="w = 1")
ax_overlay_hist.set_xlabel(r"$w_{\mathrm{PPFX\ CV}}$", fontsize=11,
                           weight="bold")
ax_overlay_hist.set_ylabel("density", fontsize=11, weight="bold")
ax_overlay_hist.set_title("Overlay: weight distributions (area-normalized)",
                          fontsize=11)
ax_overlay_hist.legend(loc="upper right", fontsize=10)
ax_overlay_hist.grid(alpha=0.3)

# Ratio of profiles: numubar / numu, per E_nu bin
mean_numu = flavors["numu"]["prof_mean"]
mean_numubar = flavors["numubar"]["prof_mean"]
sem_numu = flavors["numu"]["prof_sem"]
sem_numubar = flavors["numubar"]["prof_sem"]

with np.errstate(divide="ignore", invalid="ignore"):
    ratio = np.where(
        (mean_numu > 0) & np.isfinite(mean_numu) & np.isfinite(mean_numubar),
        mean_numubar / mean_numu,
        np.nan,
    )
    # Standard error of a ratio of two independent means
    ratio_err = np.where(
        np.isfinite(ratio) & (mean_numu > 0),
        np.abs(ratio) * np.sqrt(
            (sem_numubar / mean_numubar) ** 2 + (sem_numu / mean_numu) ** 2
        ),
        np.nan,
    )

valid_ratio = np.isfinite(ratio)
ax_overlay_ratio.errorbar(
    enu_centers[valid_ratio], ratio[valid_ratio],
    yerr=ratio_err[valid_ratio],
    fmt="o-", markersize=4, color="purple",
    capsize=2, elinewidth=1, linewidth=1.2,
)
ax_overlay_ratio.axhline(1.0, color="black", linestyle="--",
                         linewidth=1, alpha=0.5)
ax_overlay_ratio.set_xlabel(r"$E_\nu^{\mathrm{true}}$ [GeV]", fontsize=11,
                            weight="bold")
ax_overlay_ratio.set_ylabel(
    r"$\langle w \rangle_{\bar{\nu}_\mu} \,/\, \langle w \rangle_{\nu_\mu}$",
    fontsize=11, weight="bold",
)
ax_overlay_ratio.set_title("Ratio of profiles (numubar / numu)", fontsize=11)
ax_overlay_ratio.grid(alpha=0.3)
ax_overlay_ratio.set_xlim(ENU_MIN, ENU_MAX)

plt.tight_layout()
plt.savefig(OUTPUT_PNG, dpi=150, bbox_inches="tight")
print(f"\nSaved plot to: {OUTPUT_PNG}")
plt.show()
# Out:
# Opening file: /Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam_withPCA.root
# Loaded 98983 events from events/full/selected
#   Total physical entries:     98873
#   numu    (pdg == +14):       91834
#   numubar (pdg == -14):       7039
#   Other (nue/nuebar/etc.):    0
#
# numu: N=91834, mean=0.9478, std=0.0195 (2.06% of mean), range=[0.9281, 1.1283]
# numubar: N=7039, mean=0.9339, std=0.0394 (4.21% of mean), range=[0.9101, 1.0567]
#
# Saved plot to: /Users/rvizarreta/ppfx_vs_enu_by_flavor.png
