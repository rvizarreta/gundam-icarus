# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.plot_scatter import plot_scatter
from src.plot_manual_cross_section import overlay_manual_cross_section
from src.plot_fit_constraints import plot_fit_constraints
from src.plot_gundam_stacked import plot_gundam_stacked
from src.plot_GENIE_NUISANCE import overlay_genie_nuisance_xsec
from src.plot_matrices import plot_both_matrices

# %%
# Pre-fit plot
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/prefit_fakeData_InteractionMode_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
    sample_name='selection_reco_dpT',
    is_data=True,
    variable_name='reco_dpT_lp',
    cov_bin_range=(0, 12), # Covariance matrix elm, cont all range (overflow bin inclusive)
    fit_type='pre-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Mock Data Pre-fit' + '\n' + 'Work-in-Progress',
    output_file='../Plots/dpT/FakeData_InteractionMode/Prefits/prefit_dpT.png',
    pot=r'NuMI MC 7.79 $\times 10^{20}$ POT',
)

# Post-fit plot with custom settings
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/postfit_fakeData_InteractionMode_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
    sample_name='selection_reco_dpT',
    is_data=True,
    variable_name='reco_dpT_lp',
    cov_bin_range=(0, 12), # Covariance matrix elm, cont all range (overflow bin inclusive)
    fit_type='post-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Mock Data Post-fit' + '\n' + 'Work-in-Progress',
    pot=r'NuMI MC 7.79 $\times 10^{20}$ POT',
    output_file='../Plots/dpT/FakeData_InteractionMode/Postfits/postfit_dpT.png'
)

# %%
# Pre-fit plot
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/prefit_fakeData_InteractionMode_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
    sample_name='sideband_reco_dpT',
    is_data=True,
    variable_name='reco_dpT_lp',
    cov_bin_range=(13, 25), # Covariance matrix elm
    fit_type='pre-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Mock Data Pre-fit' + '\n' + 'Work-in-Progress',
    output_file='../Plots/dpT/FakeData_InteractionMode/Prefits/prefit_dpT_sideband.png',
    pot=r'NuMI MC 7.79 $\times 10^{20}$ POT',
)

# Post-fit plot with custom settings
fig, axes, chi2_info = plot_gundam_stacked(
    postfit_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/postfit_fakeData_InteractionMode_dpT.root',
    fitterengine_file_path='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
    sample_name='sideband_reco_dpT',
    is_data=True,
    variable_name='reco_dpT_lp',
    cov_bin_range=(13, 25), # Covariance matrix elm
    fit_type='post-fit',
    xlabel=r'$\delta p_T$ $\mathbf{[MeV/c]}$',
    title=r'$\bf{ICARUS \cdot NuMI}$ Mock Data Post-fit' + '\n' + 'Work-in-Progress',
    pot=r'NuMI MC 7.79 $\times 10^{20}$ POT',
    output_file='../Plots/dpT/FakeData_InteractionMode/Postfits/postfit_dpT_sideband.png'
)

# %%
fig_xs, ax_xs, xsec_extracted_raw, xsec_extracted_errors_raw = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/XSection/dpT/FakeData_InteractionMode/fakeData_InteractionMode_XSec_dpT.root',
        is_cross_section = True,
        hist_path="calcXsec/histograms/True_dpT_XS_TH1D;1",
        xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
        ylabel=r'$\frac{d\sigma}{d\delta p_T}$ $\left[\frac{cm^2}{(GeV/c)Ar}\right]$ $\times 10^{-37}$',
        bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress',
        label="ICARUS Mock Data",
        pot=r'NuMI MC 7.79 $\times 10^{20}$ POT',
        scaling_power_of_10=1e40
)
fig_xs.savefig('../Plots/dpT/FakeData_InteractionMode/XSection/dpT_XS.png', dpi=300, bbox_inches='tight')

# %%
# Scale extracted (same as working Asimov call)
xsec_extracted = xsec_extracted_raw * 1e40
xsec_extracted_errors = xsec_extracted_errors_raw * 1e40

# Overlay 1: nominal GENIE vs extracted
fig_xs, ax_xs, xsec_nominal, chi2_nominal = overlay_genie_nuisance_xsec(
    fig_xs, ax_xs,
    nuisance_file_dir="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    bin_edges=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.80],
    nuisance_var='ICARUS_1muNp0pi_deltaPT',
    scaling_power_of_10=1e37,
    label='AR23_20i',
    color='steelblue',
    reweight_mode=None,
    extracted_xsec=xsec_extracted,
    extracted_xsec_errors=xsec_extracted_errors,
)

# Overlay 2: QE-suppressed truth vs extracted
fig_xs, ax_xs, xsec_qe, chi2_qe = overlay_genie_nuisance_xsec(
    fig_xs, ax_xs,
    nuisance_file_dir="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    bin_edges=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.80],
    nuisance_var='ICARUS_1muNp0pi_deltaPT',
    scaling_power_of_10=1e37,
    label='AR23_20i (×0.8 RES)',
    color='darkorange',
    reweight_mode='RES_0p8',
    extracted_xsec=xsec_extracted,
    extracted_xsec_errors=xsec_extracted_errors,
)

fig_xs.savefig('../Plots/dpT/FakeData_InteractionMode/XSection/dpT_XS_wGENIE.png', dpi=300, bbox_inches='tight')
display(fig_xs)
# Out:
# ...
# GENIE NUISANCE Cross-Section (ICARUS_1muNp0pi_deltaPT)
# ...
# Bin range                                 xsec
# ----------------------------------------------------------------------
#   0.0000 – 0.0800           6.650362e-01
#   0.0800 – 0.1600           1.177102e+00
#   0.1600 – 0.2400           1.021994e+00
#   0.2400 – 0.3200           5.790870e-01
#   0.3200 – 0.5200           4.070161e-01
#   0.5200 – 0.8000           2.123241e-01
# ...
#
# χ² / Ndof = 5.1 / 6 = 0.854
# p-value = 0.528
#
# ...
# GENIE NUISANCE Cross-Section (ICARUS_1muNp0pi_deltaPT) [RES_0p8]
# ...
# Bin range                                 xsec
# ----------------------------------------------------------------------
#   0.0000 – 0.0800           6.602054e-01
#   0.0800 – 0.1600           1.163220e+00
#   0.1600 – 0.2400           1.001785e+00
#   0.2400 – 0.3200           5.576655e-01
#   0.3200 – 0.5200           3.908830e-01
#   0.5200 – 0.8000           2.031410e-01
# ...
#
# χ² / Ndof = 5.7 / 6 = 0.949
# p-value = 0.458

# %%
# Overlay GENIE with chi2
# Scale to 1e37 for GENIE comparison (no file re-opening needed)
xsec_extracted = xsec_extracted_raw * 1e40
xsec_extracted_errors = xsec_extracted_errors_raw * 1e40

fig_genie, ax_genie, xsec_genie, chi2_info = overlay_genie_nuisance_xsec(
    fig_xs, ax_xs,
    nuisance_file_dir = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu14",
    nuisance_file_dir_numubar = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com"
    "/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects"
    "/ICARUS/ICARUS_CC0pi_GUNDAM/data/Generators/fhc_Nu-14",
    bin_edges         = [0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.80],
    nuisance_var      = 'ICARUS_1muNp0pi_deltaPT',
    scaling_power_of_10 = 1e37,   # match whatever scaling you used in plot_scatter
    label             = 'GENIE AR23_20i',
    extracted_xsec=xsec_extracted,
    extracted_xsec_errors=xsec_extracted_errors,
)
fig_genie.savefig('../Plots/dpT/FakeData_InteractionMode/XSection/dpT_XS_wGENIE.png', dpi=300, bbox_inches='tight')
display(fig_genie)

# %%
fig_template, ax_template, dummy, dummy2 = plot_scatter(
        filename='/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
        is_cross_section = False,
        hist_path="FitterEngine/postFit/Hesse/errors/Template Parameter true_dpT_lp_genie/values/postFitErrors_TH1D;1",
        xlabel=r'$\mathbf{True}$ $\delta_{pT}$ $\mathbf{[GeV/c]}$',
        ylabel='$\mathbf{Template\ Parameter\ Value\ Post-fit}$',
        bin_edges_labels=[0.0, 0.08, 0.16, 0.24, 0.32, 0.52, 0.8],
        is_y_errors = True,
        title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress',
        label=None,
        hline_nuisance=True,
        pot=r'NuMI MC 7.79 $\times 10^{20}$ POT'
)
fig_template.savefig('../Plots/dpT/FakeData_InteractionMode/TemplateParameters/dpT.png', dpi=300, bbox_inches='tight')

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root",
    figsize=(7, 10),
    directory_path="FitterEngine/postFit/Hesse/errors/Cross section Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress'
)
fig.savefig('../Plots/dpT/FakeData_InteractionMode/NuisanceParameters/dpT_InteractionModel.png', dpi=300, bbox_inches='tight')

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root",
    figsize=(7, 5),
    y_label=r'$\mathbf{Flux\ Parameter}$',
    directory_path="FitterEngine/postFit/Hesse/errors/Multisigma Flux Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress'
)
fig.savefig('../Plots/dpT/FakeData_InteractionMode/NuisanceParameters/dpT_Flux.png', dpi=300, bbox_inches='tight')

# %%
# Usage
fig, ax = plot_fit_constraints(
    filename="/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root",
    figsize=(7, 3),
    y_label=r'$\mathbf{Detector\ Parameter}$',
    directory_path="FitterEngine/postFit/Hesse/errors/Detector Systematics/values",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress'
)
fig.savefig('../Plots/dpT/FakeData_InteractionMode/NuisanceParameters/dpT_Detector.png', dpi=300, bbox_inches='tight')

# %%
BASE = "FitterEngine/postFit/Hesse/errors"
(fig_cov, ax_cov), (fig_corr, ax_corr) = plot_both_matrices(
    '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
    figsize=(8, 20),
    cov_path  = f"{BASE}/Cross section Systematics;1/matrices/Covariance_TH2D;1",
    corr_path = f"{BASE}/Cross section Systematics;1/matrices/Correlation_TH2D;1",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress',
    annotate=True,
)
fig_cov.savefig("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/FakeData_InteractionMode/Postfits/xsec_param_covariance.png",   bbox_inches="tight")
fig_corr.savefig("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/FakeData_InteractionMode/Postfits/xsec_param_correlation.png",   bbox_inches="tight")

# %%
BASE = "FitterEngine/postFit/Hesse/errors"
(fig_cov, ax_cov), (fig_corr, ax_corr) = plot_both_matrices(
    '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
    figsize=(6, 15),
    label_name=r"$\mathbf{Flux\ Parameter}$",
    cov_path  = f"{BASE}/Multisigma Flux Systematics;1/matrices/Covariance_TH2D;1",
    corr_path = f"{BASE}/Multisigma Flux Systematics;1/matrices/Correlation_TH2D;1",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress',
    annotate=True,
)
fig_cov.savefig("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/FakeData_InteractionMode/Postfits/flux_param_covariance.png",   bbox_inches="tight")
fig_corr.savefig("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/FakeData_InteractionMode/Postfits/flux_param_correlation.png",   bbox_inches="tight")

# %%
BASE = "FitterEngine/postFit/Hesse/errors"
(fig_cov, ax_cov), (fig_corr, ax_corr) = plot_both_matrices(
    '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/data/Fitter/dpT/FakeData_InteractionMode/fakeData_InteractionMode_dpT.root',
    figsize=(5, 15),
    label_name=r"$\mathbf{Detector\ Parameter}$",
    cov_path  = f"{BASE}/Detector Systematics;1/matrices/Covariance_TH2D;1",
    corr_path = f"{BASE}/Detector Systematics;1/matrices/Correlation_TH2D;1",
    title_line1=r'$\bf{ICARUS \cdot NuMI}$ Mock Data' + '\n' + 'Work-in-Progress',
    annotate=True,
)
fig_cov.savefig("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/FakeData_InteractionMode/Postfits/detector_param_covariance.png",   bbox_inches="tight")
fig_corr.savefig("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_GUNDAM/gundam-icarus/Notebooks/Plots/dpT/FakeData_InteractionMode/Postfits/detector_param_correlation.png",   bbox_inches="tight")
